# %%
c=299792458;u=4E-7*3.1415;s=1/(u*c*c);n=sqrt(u*s);u,s,n^2
# Out:
# (1.25660000000000e-6, 8.85444895793107e-12, 1.11265005605362e-17)

# %%
0.0000000000000000111265005605362
w=1/(n*n);w
898755178736818
# Out:
# 898755178736818

# %%
a=898755178736818;sqrt(w)
# Out:
# 2.99792458000000e8

# %% [markdown]
# $k=\frac {2\pi}{\lambda} $ $hw=chk$
#
# E = h.w c'est l'énergie du photon
#
# p = h.k c'est l'impulsion du photon
#
# qui donne la relation bien connue :
#
# E = p.c qui lie l'énergie d'un photon à son impulsion
#
# $E=h\nu$  en terme de longueur d'onde $E=\hbar ck$
#
# k = nombre d'onde angulaire ( inverse de la longueur d'onde )

# %%
f=1/(2*N(pi)*sqrt(u*s));f
# Out:
# 4.77134515923694e7

# %%
cc=circle((0,0),0.5*2)
v=circle((0,0),0.477*2)
show(cc+v,figsize=4)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Maxwell-Gauss :
# $\overrightarrow{\nabla}.\overrightarrow{E}=\frac{\rho}{\epsilon_0}$
#
# Longueur d'onde = Diamètre
#
# Fréquence = Rayon = D/2

# %% [markdown]
# L'équation inachevée de Maxwell : 4 équations réduites à une seule, la clé de voute de EM.
#
# $ \vec{\nabla} \cdot \vec{E}  =  \frac{\rho}{\varepsilon_0}  =  \frac{\mu}{\varepsilon_0} = Z = zz $ et z = 360° ou 360 $\Omega$

# %%
show(LatexExpr(
r"Valeur \ numérique \ actuelle \ Z=142122 : z=376,730 \Omega  \ {\approx} "))
show(LatexExpr("Z=z^2=zz"))
show(LatexExpr(""))
# Out:
# Valeur \ numérique \ actuelle \ Z=142122 : z=376,730 \Omega  \ {\approx}
# Z=z^2=zz
# \begin{math}
# \newcommand{\Bold}[1]{\mathbf{#1}}
# \end{math}

# %%
# %display latex
#120*(n(pi,digits=33))

# %%
#(120*(n(pi,digits=33)))^2

# %%
c=299792548;mu=n(pi)*4E-7;epsilon=1/(mu*c*c)
z=sqrt(mu/epsilon);z

# %% [markdown]
# Afin de respecter les antiques valeurs :
#
# $z=360°=360\Omega$ : 1 degré = 1 ohm
#
# Fréquence Angulaire de la célérité c : ç=314159265 rad/s, FA=ç=chiracécité
#
# Un cercle = 360°  Une ellipse=376.730 $\Omega$

# %%
#from sage.plot.ellipse import Ellipse

# %%
C=ellipse((0,0),1.299792458,1,color="green",
legend_label="c", legend_color='green');C
ç=circle((0,0),1.3141592653,color="red",
legend_label="ç",legend_color='red');ç
show(C+ç,axes=False)
# Out:
# Graphics object consisting of 2 graphics primitives
