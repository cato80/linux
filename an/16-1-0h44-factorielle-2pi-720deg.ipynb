# %% [markdown]
# Quel est le rapport entre (6)! 720° et 2$\pi$ rad ?

# %%
# %display latex
factorial(1/2)
# Out:
# 1/2*sqrt(pi)

# %%
factorial(6)
# Out:
# 720

# %%
deg(x)=x*180/n(pi);int(deg(4*n(pi)))
# Out:
# 720

# %%
deg(0.10965903690280)
# Out:
# 6.28299999999979

# %%
rad(x)=x*n(pi)/180;rad(2*3.1415)
# Out:
# 0.109659036902804

# %%
zeta(2)
# Out:
# 1/6*pi^2

# %%
zeta(2.0)
# Out:
# 1.64493406684823

# %%
deg(zeta(8.0))
# Out:
# 57.5293948147960

# %%
deg(1)
# Out:
# 57.2957795130823

# %%
deg(zeta(221.0))==deg(1)
# Out:
# 57.2957795130823 == 57.2957795130823

# %% [markdown]
# ###### Eurêka ! A 1 heure du matin !
