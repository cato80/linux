# %% [markdown]
# https://www.collectionscanada.gc.ca/eppp-archive/100/200/300/gabriel_lafreniere/matiere_ondes-e/ondes.htm
#
# Il est parti pour l'éternité, un peu amer parce-que peu s'intérêssait à son travail...

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Cette figure est fausse et incomplète : Elle ne tient pas compte du pouvoir rotatoire de la lumière !
#
# Voici ma conception de la réalité :

# %%
import warnings;warnings.filterwarnings('ignore')
cc=circle((0,0),1,color="black");
c0=circle((-0.50,0),0.5,color="red")
c4=circle((-0.45,0.37),0.45,color="red")
c6=circle((-0.35,0.48),0.40,color="red")
c8=circle((-0.25,0.57),0.35,color="red")
c10=circle((-0.15,0.67),0.30,color="red")
c1=circle((0.5,0),0.5,color="blue")
c3=circle((0.45,-0.36),0.45,color="blue")
c5=circle((0.35,-0.46),0.40,color="blue")
c7=circle((0.25,-0.56),0.35,color="blue")
c9=circle((0.15,-0.66),0.30,color="blue")
show(cc+c0+c1+c3+c4+c5+c6+c7+c8+c9+c10,
    figsize=3,fontsize=5)
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
cm=circle((-0.015,0.015),0.25,color="green")
c10=circle((-0.15,0.67),0.30,color="red")
c12=circle((0.25,0.71),0.23,color="red")
c11=circle((-0.25,-0.7),0.25,color="blue")
c13=circle((-0.52,-0.66),0.15,color="blue")
show(cc+c0+c1+c3+c4+c5+c6+c7+\
     c8+c9+c10+c11+c12+c13+cm,
    figsize=3,fontsize=5)
# Out:
# Graphics object consisting of 15 graphics primitives

# %%
p=plot(x,-0.7,0.7,color="brown");
q=plot(-x,-0.7,0.7,color="salmon")
show(cc+c0+c1+c3+c9+c10+c12+cm+p+q,
    figsize=3,fontsize=5,gridlines="minor")
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',
       fill=sqrt(4-x^2),fillcolor="black",alpha=0.1)
b=plot(f,(x,-2,2),color='white',
       fill=-sqrt(4-x^2),fillcolor="red",alpha=0.1)
show(a+b,figsize=2,axes=False,aspect_ratio=1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
cc=circle((0,0),2,color="black");
p=plot(x,-0.7,0.7,color="brown");
q=plot(-x,-0.7,0.7,color="salmon")
show(a+b+cc+c0+c1+c3+c9+c10+c12+cm+p+q,
    figsize=3,fontsize=5,gridlines="major")
# Out:
# Graphics object consisting of 14 graphics primitives

# %%
cc=circle((0,0),2,color="black");
c0=circle((-1,0),1,color="blue")
c1=circle((1,0),1,color="red")
c2=circle((0,1.35),0.65,color="red")
c3=circle((0,-1.35),0.65,color="blue")
c4=circle((0.45,-0.37),0.5,color="blue")
show(a+b+c0+c1+c3,
figsize=3,fontsize=5,gridlines="major")
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
# %display latex # (4)
c=299792458;a=7.2973525664E-3;Me=9.10938356E-31
h=6.626E-34;hb=h/(2*n(pi));hb=h/(n(pi)*2);
G=6.67384E-11;Lp=sqrt(hb*G/2*n(pi)*c^3);B=(3-sqrt(5.0))
show(LatexExpr(r"L_p=ct_p=\sqrt \frac{h G}{2\pi c^3}\
="),Lp,LatexExpr(r"m"))
# Out:
# L_p=ct_p=\sqrt \frac{h G}{2\pi c^3}\
# = 5.45776296252257e-10 m

# %%
Mp=sqrt(h*c/(2*n(pi)*G)) #(5)
show(LatexExpr(r"M_p=\sqrt \frac{h c}{2 \pi G}\
="),Mp,LatexExpr(r"kg"))
# Out:
# M_p=\sqrt \frac{h c}{2 \pi G}\
# = 2.17649782635443e-8 kg

# %% [markdown]
# http://www.pragtec.com/physique/#anchor20
#
# $N$ en fonction de la constante de structure fine $\alpha$, (page 7 alinéa : 2.4)
#
# $N=\frac{1}{\alpha^{57}}\approx 6.303419702\times10^{121}$
#
# Comme elle n'est relié à aucune référence connue, je pencherais pour $2\pi$ puissance 121. Car la constante $\pi$ est un référentiel intangible.
#
# Donc $\Omega=\frac{1}{\alpha^{57}}=  2 \pi^{121} \times10^{121}$

# %%
O=(2*n(pi))*1E121;show(LatexExpr(r"\Omega ="))
# Out:
# \Omega =

# %% [markdown]
# ##### Calcul du rayon classique de l'électron
#
# $r_e=\frac{1}{4\pi \epsilon_0}$ $\frac{e^2}{m c^2}$ = $2.817940325 \times 10^{-15} m$
#
# Le premier rapport est $k$ coefficient de Coulomb.

# %%
mu=4*3.141592653E-7;c=299792458;ep=1/(mu*c*c)
e=1.60E-19;m=9.10E-31;k=1/(ep*(mu/1E-7))
Re=(1/k)*(e^2/m*c^2);Re=2.817940E-15

# %%
a=1/137.0;B=3-sqrt(5.0);pars=96939420213600000000/n(pi)
H0=(c*(a^19)*(sqrt(B)))/Re;Hu=H0*(pars)
show(LatexExpr(r"H_0=\frac{c a^{19} \sqrt B}{r_e}="),H0,"m")
show(LatexExpr(r"H_0\frac{MParsec}{1000}="),Hu," km/s")
# Out:
# H_0=\frac{c a^{19} \sqrt B}{r_e}= 2.34814841311843e-18 'm'
# H_0\frac{MParsec}{1000}= 72.4562891637406 ' km/s'

# %%
Me=m;1/a^20 #postulat 2 page 18
# Out:
# 5.42514491120474e42

# %%
G=((c^2)*Re*(a^20))/(Me*B);G
# Out:
# 6.71530429699786e-11

# %% [markdown]
# La vitesse de la lumière est un mirage scientifique : La lumière $c$ n'est pas une vitesse mais une fréquence angulaire $\omega=2\pi f =\frac{1}{\sqrt LC}$ = ç, à qui j'ai donné le nom de $ç$ = çhiracécité = çhiracecity), chira=double.

# %%
L=1/n(pi)*360E-8;show("L=",L)
C=1/(n(pi)*360E+8);show("C=",C)
w=1/sqrt(L*C)
show(LatexExpr(r"ç=\frac{1}{\sqrt L C}="),round(w))
# Out:
# 'L=' 1.14591559026165e-6
# 'C=' 8.84194128288307e-12
# ç=\frac{1}{\sqrt L C}= 314159265

# %%
# %display latex
c=299792458;mu=4E-7*n(pi);ep=1/(mu*c^2)
show(LatexExpr(r"\mu="),mu)
show(LatexExpr(r"\epsilon="),ep)
show(LatexExpr(r"c=\frac{1}{\sqrt \mu\epsilon}="),c)
# Out:
# \mu= 1.25663706143592e-6
# \epsilon= 8.85418781762039e-12
# c=\frac{1}{\sqrt \mu\epsilon}= 299792458

# %%
(mu*ep)^2
# Out:
# 1.23799014723612e-34
