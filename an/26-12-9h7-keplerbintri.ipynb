# %%
# %display latex

# %%
365.25/360
# Out:
# 1.01458333333333

# %%
v=sqrt(n(pi))

# %%
v^2
# Out:
# 3.14159265358979

# %%
g=n(pi)^2;show(g);120*n(pi)/360
# Out:
# 9.86960440108936
# 1.04719755119660

# %%
el0=ellipse((0,0),1,1,
color="black",linestyle="-",thickness=3)
el1=ellipse((0,0),1.014,1,
color="red",linestyle="--",thickness=3)
el2=ellipse((0,0),1.047,1,color="green")
show(el0+el1+el2)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
n(pi)*1.047*2
# Out:
# 6.57849501661703

# %%
a=2^3;b=3^4;show(a,b)
# Out:
# 8 81

# %%
# %display latex
p=a/b;show(p,"  pipi = ",n(p))
# Out:
# 8/81 '  pipi = ' 0.0987654320987654

# %%
show("pi =",sqrt(n(p*100)),"  pipi*100 = ",n(p*100))
# Out:
# 'pi =' 3.14269680527354 '  pipi*100 = ' 9.87654320987654

# %%
pe=sqrt(n(p*100));np=round(pe,2)
show("p=np naturel (pur) = ",round(pe,2))
# Out:
# 'p=np naturel (pur) = ' 3.14

# %%
A=1;B=1;a=A*B/2;T=1;k=T^2/a^3;show(k)
# Out:
# 8
