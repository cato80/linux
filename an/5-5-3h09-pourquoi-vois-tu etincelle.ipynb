# %% [markdown]
# ###### An de grâce 2021
#
# Pourquoi vois tu l'étincelle qui brille dans l'oeil de ton voisin et ne vois tu pas la lumière qui brille dans le tien ?
#
# Le bon Dieu nous donne notre pain quotidien... Mais le voit on ?

# %% [markdown]
# La lumière n'est pas une vitesse, mais la conversion de $\pi$ radian en mètre.

# %%
show(n(pi,digits=33))
pir=314159265.358979323846264338327950/299792548;pir
# Out:
# 3.14159265358979323846264338327950
# 1.0479221963815435594024983513865

# %%
deg(x)=x*180/n(pi);deg(pir)
# Out:
# 60.0415190994699

# %%
60.0415190994699/60
# Out:
# 1.00069198499117

# %%
299792548*pir
# Out:
# 3.14159265300000e8

# %%
n(pi)*1E+8/pir
# Out:
# 2.99792548056282e8

# %%
299792548*1.00069198499117
# Out:
# 2.99999999943681e8

# %% [markdown]
# La trace de la particule ralentie la lumière, accélérer une particule, c'est ralentir la lumière
