# %% [markdown]
# ##### Science obsolete
#
# La seule constante universelle, fondation de toutes les autres constantes est $\pi$.

# %%
# %display latex
#n(pi,digits=1000000)
C=1/(n(pi)*360E+8);C
# Out:
# 8.84194128288307e-12

# %%
rad(x)=x*n(pi)/180;
RC=rad(8.84194128288307E-12);RC
# Out:
# 1.54320987654321e-13

# %%
RC*1E13
# Out:
# 1.54320987654321

# %% [markdown]
# ###### Erreur fondamentale
#
# La lumière n'est pas une vitesse : L'équation de la célérité est une formule de $F_a$ : Fréquence angulaire, pour faire court je lui donne le nom de chiracécité = $ç$, (double cécité !)

# %%
u=1/n(pi)*360E-8;s=1/(n(pi)*360E+8);
ç=(1/sqrt(u*s));ç
# Out:
# 3.14159265358979e8

# %% [markdown]
# L'inductance $L=u=\mu$ et Capacitance $C=s=\epsilon$
#
# La chiracécité $ç$ est l'inverse de la racine carrée du produit de la perméabilité par la permittivité.
#
# Elle correspond a un multiple de $\pi$ qui devient un référentiel juste, de grandeur. La précision ne dépend que du nombre de décimal que l'on souhaite.
#
# On obtient dans ce système : L'accélération $\pi^2=c^2=ç^2$
#
# La vitesse qui est toujours la dérivé de l'espace par rapport au temps ( et non un espace-temps !)
#
# $v=2ç=2c=2\pi$
#
# La position $\pi$=[-1,0,1]

# %%
çç=1/(u*s);çç
# Out:
# 9.86960440108936e16

# %% [markdown]
# C'est bien Leibniz qui avait raison $E=mc^2=VisViva=mv^2$ !
#
# Depuis plus de 300 ans, l'académie des sciences nous enfument contre la quadrature du cercle et l'accélération.
#
# Le conservatisme des idées en entrainent l'obsolescence : Dans $E=mc^2$ ce n'est pas la masse qui produit l'énergie, mais la célérité $c^2$ ou $c \times c$, donc déplacement ou mouvement supérieur à $ç>c$, ainsi l'on voit que la célérité n'est pas la vitesse maximum, j'introduit $ç$ comme vitesse ($F_a=\omega$) supérieure de valeur $ç=314159265.3$ la décimale étant la précision qui peut aller à un nombre infinie.

# %%
E=ç^2;E
# Out:
# 9.86960440108936e16

# %% [markdown]
# En fait la masse ralentie $ç^2$ qui devient $c$, pour faire court j'appelle ç=chiracécité=çhira (prononcer sira=çira, comme "il çira mes bottes ! lol :)
#
# $E=$ Energie supraluminique = bot=$B$
#
# Rien n'empêche de bien rigoler ! C'est tellement déprimant de ne pas être écouté !

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://fr.wikipedia.org/wiki/Loi_de_Coulomb_(m%C3%A9canique)
#
# adhérence et glissement
#
# Hystérésis = seuil photo électrique (travail d'extraction)
