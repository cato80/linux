# %%
# %display latex
var("f R L C w")
show(L*w==1/(C*w))
show(w*w==1/(L*C))
show(2*pi*f*L==1/(2*pi*f*C))
show(4*pi^2*f^2*L*C==1)
# Out:
# L*w == 1/(C*w)
# w^2 == 1/(C*L)
# 2*pi*L*f == 1/2/(pi*C*f)
# 4*pi^2*C*L*f^2 == 1

# %%
solve(4*pi^2*f^2*L*C==1,f)
# Out:
# [f == -1/2*sqrt(1/(C*L))/pi, f == 1/2*sqrt(1/(C*L))/pi]

# %%
solve(4*pi^2*f^2*L*C==w,C)
# Out:
# [C == 1/4*w/(pi^2*L*f^2)]

# %%
solve(4*pi^2*f^2*L*C==4*pi^2*f,f)
# Out:
# [f == 1/(C*L), f == 0]

# %% [markdown]
# Il apparait que $f$ est la fréquence angulaire $w$ au carrée $w^2$ et que $f=c$

# %%
solve(4*pi^2*f^2*L*C==4*pi^2*w,w)
# Out:
# [w == C*L*f^2]

# %%
var("mu epsilon c")
# Out:
# (mu, epsilon, c)

# %%
show(mu*epsilon*c^2==1)
# Out:
# c^2*epsilon*mu == 1

# %%
solve(mu*epsilon*c^2==1,c)
# Out:
# [c == -sqrt(1/(epsilon*mu)), c == sqrt(1/(epsilon*mu))]

# %%
solve(f^2*L*C==1,f)
# Out:
# [f == -sqrt(1/(C*L)), f == sqrt(1/(C*L))]

# %%
w=2*pi*f;w
# Out:
# 2*pi*f

# %%
solve(2*pi*f==1,f)
# Out:
# [f == 1/2/pi]

# %%
solve(w==2,f)
# Out:
# [f == (1/pi)]

# %%
solve(w==2*pi,f)
# Out:
# [f == 1]

# %%
var("alpha Omega")
# Out:
# (alpha, Omega)

# %%
ç=1/sqrt(alpha*Omega)
show(LatexExpr(r"ç=\frac{1}{\sqrt \alpha \Omega}"))
# Out:
# ç=\frac{1}{\sqrt \alpha \Omega}

# %%
1/2*n(pi)-1/(2*n(pi))
# Out:
# 1.41164138370300

# %%
solve(R^2*L*C==1,R)
# Out:
# [R == -sqrt(1/(C*L)), R == sqrt(1/(C*L))]

# %% [markdown]
# La pulsation propre ou de résonance d'un circuit LC (en radians par seconde) est : $w_0$

# %%
show(solve(mu*epsilon*c^2==0,c))
show(solve(mu*epsilon*c^2==1,c))
# Out:
# [c == 0]
# [c == -sqrt(1/(epsilon*mu)), c == sqrt(1/(epsilon*mu))]

# %%
1/(2*n(pi))*1/2*n(pi)*4
# Out:
# 1.00000000000000

# %%
show(1/(2*pi)*1/2*pi*4)
# Out:
# 1

# %%
Q=(1/377)*377;Q
# Out:
# 1
