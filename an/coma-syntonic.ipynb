# %% [markdown]
# https://fr.wikipedia.org/wiki/Comma_syntonique
#
# ![image.png](attachment:image.png)

# %%
1/(81.0/80),81.0/80
# Out:
# (0.987654320987654, 1.01250000000000)

# %% [markdown]
# Le coma syntonique correspond à la base 10, moins le 1, qui en fait une base neuvième.
# C'est une suite finie si le 0 est fini et infini, si le zéro ne l'est pas. La racine carrée donne $\pi$ au centième.

# %%
sqrt(9.876543210)
# Out:
# 3.14269680529319

# %%
81/64.0
# Out:
# 1.26562500000000

# %% [markdown]
# En fait le comma pythagoricien n'est pas seulement un élément de musique, mais il correspond à la racine carrée de $\pi$ naturelle, calculée depuis la base décimale ou le 1 n'apparait pas.

# %%
314159265.3/299792458 # comma lumière Fa
# Out:
# 1.04792251077911

# %% [markdown]
# Intervalle : rapport entre fréquences
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dans le cadres de la lumière la masse n'existe plus, c'est un état, il y a ainsi 3 états -1 0 1
