# %% [markdown]
# ##### Math&physique
#
# Le physiquement correct aujourd'hui apparait comme devant parler en dimension ?
#
# Pourquoi rendre difficile ce qui est simple ?
#
# Formule : $v=\frac{x}{t}$ Dimension : $V=LT^-1$
#
# Je comprends que les étudiants puissent être troublés par cet emploi : Je ne l'utilise pas car les calculs précis qu'on doit obtenir ne sont pas des résultats de dimension mais des résultats numériques. Mettre $\pi$ en dimension est complétement erroné.

# %%
# %display latex
n(pi,digits=35)
# Out:
# 3.1415926535897932384626433832795029

# %%
31415926535897932384626433832795029/\
10000000000000000000000000000000000
# Out:
# 31415926535897932384626433832795029/10000000000000000000000000000000000

# %%
3141592653589793238462643383279502/\
10000000000000000000000000000000000
# Out:
# 1570796326794896619231321691639751/5000000000000000000000000000000000

# %% [markdown]
# Après le zéro il faut un nombre impair pour pouvoir diviser et retrouver le bon résultat, avec un nombre pair la division est calculée et le résultat est un multiple de $\pi$

# %% [markdown]
# Les scientifiques n'ont pas compris ce qu'était l'éther alors ils l'ont abandonnée, erreur fondamentale. Mon analyse de l'éther a pour résultat une impédance (résistance) au vide, c'est pourquoi la célérité des particules est de $c$, mais ce n'est que la vitesse limite des particules visibles. Il faut une vitesse de v=Z=0 et cela n'est obtenue qu'au moment de la résonnance.

# %%
A=2*1E-7;round(A,7)  # Newton
# Out:
# 2e-07

# %%
c=299792458;2==1+1   # Watt heure = 3600 J kW=3600kJ
# Out:
# True

# %% [markdown]
# 1 Joule = 1 A x 1 $\Omega$ = 1Ws 1 kg $m^2 s$*
#
# 1 eV=1.60217733E-19 J et  1J=6.24150636309E+18 eV

# %%
eV=n(pi)*2*1E+18;eV  #eV
# Out:
# 6.28318530717959e18

# %%
J=1/eV;J #joules
# Out:
# 1.59154943091895e-19

# %%
show(LatexExpr("Electron \\ volt \\ : 1eV ="),eV)

show(LatexExpr("inverse \\ eV : 1 joule ="),J)
# Out:
# Electron \ volt \ : 1eV = 6.28318530717959e18
# inverse \ eV : 1 joule = 1.59154943091895e-19

# %% [markdown]
# http://arsene.perez-mas.pagesperso-orange.fr/physique/electricite/statique/Statique04_Coulomb.htm
#
#
# ![image.png](attachment:image.png)

# %%
f=pi^2*1/pi^2;f
u=1E7;cc=c^2

# %%
show(LatexExpr(
r"Force=fréquence=f=\pi^2 \times\frac{1}{\pi^2}="),f)
# Out:
# Force=fréquence=f=\pi^2 \times\frac{1}{\pi^2}= 1

# %%
show(LatexExpr(
r"Force=fréquence=f=\pi^2 \times\frac{1}{\pi^2}\times u="),
     round(u,7))
# Out:
# Force=fréquence=f=\pi^2 \times\frac{1}{\pi^2}\times u= 10000000.0

# %%
show(LatexExpr(
r"k_c=\frac{ç^2}{u} ="),round(cc/10000000.0)," N")
# Out:
# k_c=\frac{ç^2}{u} = 8987551787 ' N'

# %% [markdown]
# 1 Coulomb correspond à une force de répulsion de $k_c=$898755.1787 Tonnes
#
# 1 photon $c$ a ainsi une force de répulsion de :
# 8987551787368176,4 kg ou 8987,551787368174 TT=Tera Tonnes ou 8,9875517873681764 Pkg

# %%
1/89875517873681764.0
# Out:
# 1.1126500560536184e-17

# %%
eV
# Out:
# 6.28318530717959e18

# %%
h=6.62607015E-34;a=7.297352566417E-3;u=4E-7*n(pi)
sV=sqrt((2*h*a)/(u*c));sV,1/sV
# Out:
# (1.60217663412205e-19, 6.24150907398530e18)

# %% [markdown]
#  Ce qu'ils appellent la masse est la résistance de la particule par rapport à la lumière, ce n'est pas une masse mais une force/fréquence.
#
# C'est ce que signifie :$E=mc^2=hf$
#
# $h$ est la masse et $c^2$ la fréquence.
#
# Il n'y a pas de dualité, seulement une différence de terminalogie. Les physiciens, dont Einstein en particulier, ont fait l'erreur d'appeler $c^2$ vitesse ou célérité, ils auraient du dire : Fréquence angulaire. $c^2=\omega^2$ ou accélération !

# %%
show(LatexExpr(
r"c^2=\omega^2=\frac{1}{\mu \epsilon}"))
# Out:
# c^2=\omega^2=\frac{1}{\mu \epsilon}

# %%
show(LatexExpr(
r"c=\omega=\frac{1}{\sqrt \mu \epsilon}"))
# Out:
# c=\omega=\frac{1}{\sqrt \mu \epsilon}

# %%
show(LatexExpr(r"Fréquence \ angulaire: c=w=2 \pi f"))
# Out:
# Fréquence \ angulaire: c=w=2 \pi f

# %%
fc=299792548/(2*n(pi))
c=round(2*n(pi)*fc,8)

# %%
show(LatexExpr(r"Fréquence \ angulaire: w=c=2 \pi f="),c)
# Out:
# Fréquence \ angulaire: w=c=2 \pi f= 299792548.0

# %%
2*n(pi)/60*10
# Out:
# 1.04719755119660

# %%
3.1415926535897932384626433832795028842/299792548
# Out:
# 1.047922196381543559402498351386473717e-8

# %%
n(pi,digits=38)
# Out:
# 3.1415926535897932384626433832795028842

# %%
314159265.3/1.047922196381543559402498351386474
# Out:
# 2.99792547943718e8

# %%
314159265.3/1.047922196381543559402498351386473717
# Out:
# 2.99792547943718e8

# %%
rf=1/60.0;rf
# Out:
# 0.0166666666666667

# %%
rp=2*n(pi)/60;rp
# Out:
# 0.104719755119660

# %%
rp/rf,1/(rp/rf)
# Out:
# (6.28318530717959, 0.159154943091895)

# %%
1/n(pi)/0.159154943091895
# Out:
# 2.00000000000000

# %%
1/n(pi)*n(pi)
# Out:
# 1.00000000000000

# %%
(9.87654320/9.80665)-1
# Out:
# 0.00712712292169093

# %%
35.30394/60
# Out:
# 0.588399000000000

# %%
deg(x)=x*180/n(pi);deg(0.5883990)
# Out:
# 33.7127793697181

# %%
deg(x)=x*180/n(pi);deg(35.30394)
# Out:
# 2022.76676218309

# %%
l=1;v=n(pi);gl=v^2/2*l;gl
# Out:
# 4.93480220054468

# %%
t=1;gv=v/t;gv
# Out:
# 3.14159265358979

# %%
gt=v^2;gt # pi^2
# Out:
# 9.86960440108936

# %%
G=6.674  # 2 pi
