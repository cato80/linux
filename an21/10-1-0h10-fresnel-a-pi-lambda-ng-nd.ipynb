# %% [markdown]
# Lumière polarisée = champ électrique sinusoïdal qui peut être
# considéré comme la somme des 2 vecteurs identiques mais
# opposés. L’interaction avec une molécule non symétrique affecte
# la vitesse des vecteurs et dévie le plan de polarisation.
#
# Je n'aime pas cette définition car le champ n'existait pas à son époque.je traduis champ par éther.
#
# LP=Impédance (éther) dérivé (rapport) de 2 milieu (états) de différentes consistances : Le vide $= Z = z^2 = L/C$

# %%
c=circle((0,0),1,color="blue");o=point((0.5,0.868));
q=point((0.71,0.71));p=point((0.868,0.5));
b=line([(0,0),(0.5,0.86)],color="blue",linestyle="--")
v=line([(0,0),(0.7,0.7)],color="green",linestyle="--")
r=line([(0,0),(0.86,0.5)],color="red",linestyle="--")
show(c+p+q+o+b+v+r,gridlines="minor",figsize=3,fontsize=5)
# Out:
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2327: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   x_formatter = OldScalarFormatter()
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2352: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   y_formatter = OldScalarFormatter()
# Graphics object consisting of 7 graphics primitives

# %%
# %display latex
c0=circle((0,0),1.5,color="green");o=point((0.5,0.868));
show(c+c0+p+q+o+b+v+r,gridlines="major",figsize=3,fontsize=5)
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# La notion d'éther n'ayant pas été comprise au XX siècle, elle a été remplacée par celle de champ, qui n'est ni égale et obsolète. L'éther est l'impédance du vide (résistance), dans le cas de l'espace. Elle ne dépend que du milieu dit électrique et di-électrique. L'espace de Maxwell est de c=Qe/Qm. Mon espace est de 360° avec les changements à l'échelle : ç=314159265.3.
# La çhiracécité est une fréquence angulaire $FA=ç$. Elle est composé de 2 rapport FA# et FAb qui lorsqu'ils sont en résonances, composent la longueur d'onde $\lambda= 2\pi$, pour faire court : $fd + fb = FA $ = 2ç = $2\pi$

# %%
cb=circle((0,0),0.102355547608840,color="blue");
cv=circle((0,0),0.0723763018062732,color="green");o=point((0.5,0.868));
show(cv+cb,gridlines="minor",figsize=5,fontsize=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
1.02355547608840-0.723763018062732
# Out:
# 0.299792458025668

# %%
deg(x)=x*180/n(pi);deg(1.02355547608840)
# Out:
# 58.6454088773690

# %%
deg(x)=x*180/n(pi);deg(0.723763018062732)
# Out:
# 41.4685663026453

# %%
58.6454088773690+41.4685663026453
# Out:
# 100.113975180014

# %%
1/0.0000000000000000100113975180014
# Out:
# 9.98861545755135e16

# %%
sqrt(9.98861545755135e16)
# Out:
# 3.16047709334388e8

# %%
n(pi)/6
# Out:
# 0.523598775598299

# %% [markdown]
# Pourquoi un savant voit il la paille dans l'oeil de son collègue, alors qu'il ne voit pas la poutre qui est dans le sien ?
#
# Réponse : L'orgueil ! L'arrogance du savoir : Je sais... Il ne sait pas !  Et surtout la reconnaissance scientifique (la science est devenue un dogme), pouvoir qu'il lui est conféré comme savant !
#
# Bien sûr que la coudée est le sixième de $\pi$, et la cerise sur le gâteau : j'ai calculé le rapport entre $\pi$ et $c$ mis à l'échelle ! Cela fait 60° donc bien un sixième de $\pi$ !

# %%
py=314159265.3;c=299792458
r=py/c;r
# Out:
# 1.04792251077911

# %%
deg(r)
# Out:
# 60.0415371243953

# %%
r/60
# Out:
# 0.0174653751796518

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On voit ici que le doigt n'a rien à voir avec la coudée !
# C'est la lune : 28 j = 4*7

# %%
deg(0.0174653751796518)
# Out:
# 1.00069228540659

# %%
deg(2*n(pi)/3)
# Out:
# 120.000000000000

# %%
n(pi)*120
# Out:
# 376.991118430775

# %%
rad(x)=x*n(pi)/180;rad(376.991118430775)
# Out:
# 6.57973626739290

# %%
6.57973626739290/2*n(pi)
# Out:
# 10.3354255600999

# %%
c=circle((0,0),1,color="blue");o=point((0.5,0.868));
q=point((0.71,0.71));p=point((0.868,0.5));
b=line([(0,0),(0.5,0.86)],color="blue",linestyle="--")
v=line([(0,0),(0.7,0.7)],color="green",linestyle="--")
r=line([(0,0),(0.86,0.5)],color="red",linestyle="--")
show(c+p+q+o+b+v+r,gridlines="minor",figsize=3,fontsize=5)
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
i = CC.0;li=line([i, 0.7+0.7*i])
show(c+li+v,figsize=5,gridlines="minor",frame=False,axes=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
plot(sqrt(-x^2+2*abs(x))*sgn(-x),[x,-2,2],aspect_ratio=1,
figsize=3,fontsize=5,fill=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# %display latex
integrate(sqrt(-x^2+2*abs(x)),x,-2,2)
# Out:
# pi
