# %% [markdown]
# Je rencontre des problèmes que je solutionne en créant de nouveaux multiples,constantes.
#
# Quant on écrit 10E-34, on ne sait pas  trop où on en est, donc je propose d'utiliser le code suivant
#
# $10E+10= 1^{+d}$ et $-10=1^{-d}$  et ainsi de $10E+20= 1^{+v}$
#
# ç=chiracécité 314159265(3)
#
# u= Tension du l'espace : 1.14591559026165e-6
#
# s= Intensité de l'espace  : 8.84194128288307e-12
#
# Z= Impédance de l'espace cyclique : $z^2 =360° \Omega$

# %%
# %display latex
u=1/n(pi)*360E-8;u
# Out:
# 1.14591559026165e-6

# %%
s=1/(n(pi)*360E+8);s
# Out:
# 8.84194128288307e-12

# %%
ç=sqrt(1/(u*s));int(ç)
# Out:
# 314159265

# %% [markdown]
# L'onde est un rapport $\lambda=\frac{\omega}{f}$.
#
# La façon dont elle est décrite prête à confusion, je préferre faire l'analogie avec une note et son intervalle
#
# dans une sinusoidale la ligne zéro représente le centre.
#
# $\lambda=\frac{c}{f}$ donc zéro est un noeud.
#
# $\lambda=\frac{\frac{1}{\sqrt\mu\epsilon}}{\frac{1}{2\pi\sqrt\mu\epsilon}}$ = $\frac{c}{\nu}$=$2\pi$
#
# Donc $\lambda = 2 \pi = 6.28$

# %%
# %display latex
import warnings;warnings.filterwarnings(
"ignore",category=DeprecationWarning)

# %%
var("lambda_0 mu epsilon c nu omega") 
lo=lambda_0==(1/sqrt(mu*epsilon)/ \
(1/(2*pi*sqrt(mu*epsilon))));lo
# Out:
# lambda_0 == 2*pi

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="black",alpha=1)
b=plot(f,(x,-2,2),color="white",fill=-sqrt(4-x^2),
fillcolor="red",alpha=1)
pn = polygon(((0,0),(0,1),(0.7,0.7)),
             color="cyan",alpha=0.9)
ne = polygon(((0,0),(1,0),(0.7,0.7)),
             color="violet",alpha=0.9)
so = polygon(((0,0),(-1,0),(-0.7,-0.7)),
             color="red",alpha=0.9)
ps = polygon(((0,0),(0,-1),(0.7,-0.7)),
             color="lightgreen",alpha=0.9)
sp = polygon(((0,0),(0,1),(-0.7,0.7)),
             color="green",alpha=0.9)
se = polygon(((0,0),(1,0),(0.7,-0.7)),
             color="salmon",alpha=0.5)
es = polygon(((0,0),(-1,0),(-0.7,0.7)),
             color="yellow",alpha=0.9)
sn = polygon(((0,0),(0,-1),(-0.7,-0.7)),
             color="blue",alpha=0.9)
#L = [[cos(pi*i/4),sin(pi*i/4)] for i in range(8)]
np = polygon(((0,0),(0,8),(5.7,5.7)),
             color="cyan",alpha=0.5)
gr = polygon(((0,0),(0,8),(-5.7,5.7)),
             color="green",alpha=0.9)
en = polygon(((0,0),(8,0),(5.7,5.7)),
             color="violet",alpha=0.5)
os = polygon(((0,0),(-8,0),(-5.7,-5.7)),
             color="red",alpha=0.9)
sp = polygon(((0,0),(0,-8),(5.7,-5.7)),
             color="lightgreen",alpha=0.9)
ka = polygon(((0,0),(8,0),(5.7,-5.7)),
             color="salmon",alpha=0.9)
ja = polygon(((0,0),(-8,0),(-5.7,5.7)),
             color="yellow",alpha=0.9)
bl = polygon(((0,0),(0,-8),(-5.7,-5.7)),
             color="blue",alpha=0.9)
cc=circle((0,0),2,color="white")
show(np+en+os+sp+se+sn+sp+es+ka+gr+ja+bl+a+b+cc,
     axes=False,fontsize=6,gridlines=False,figsize=3)
# Out:
# Graphics object consisting of 17 graphics primitives

# %%
pi2=720;L=1/n(pi)*360E-8;show("L=",L)
C=1/(n(pi)*360E+8);show("C=",C);w=1/sqrt(L*C)
show(LatexExpr(r"ç=\frac{1}{\sqrt L C}="),round(w))
# Out:
# 'L=' 1.14591559026165e-6
# 'C=' 8.84194128288307e-12
# ç=\frac{1}{\sqrt L C}= 314159265

# %%
# %display latex
c=299792458;mu=4E-7*n(pi);ep=1/(mu*c^2)
show(LatexExpr(r"\mu="),mu);show(LatexExpr(r"\epsilon="),ep)
show(LatexExpr(r"c=\frac{1}{\sqrt \mu\epsilon}="),c)
# Out:
# \mu= 1.25663706143592e-6
# \epsilon= 8.85418781762039e-12
# c=\frac{1}{\sqrt \mu\epsilon}= 299792458
