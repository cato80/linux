# %% [markdown]
# ##### Fonction deg(zeta 221.0) égale 1 radian ( En degrés)
#
# $deg(zeta(221.0))==deg(1)$
#
# deg$(x)=x*180/n(pi)$;deg($zeta(221.0))==(1)$

# %%
# %display latex
rad(x)=x*n(pi)/180;rad(2*3.1415)
deg(x)=x*180/n(pi);deg(zeta(221.0))==(1)
# Out:
# 57.2957795130823 == 1

# %%
z1=deg(zeta(221.0));z2=deg(zeta(221.0));z3=deg(zeta(221.0))
z4=deg(zeta(221.0));z5=deg(zeta(221.0));z6=deg(zeta(221.0))
z7=deg(zeta(221.0));z8=deg(zeta(221.0));z9=deg(zeta(221.0))

# %%
show(z1+z2+z3+z4+z5+z6+z7)
# Out:
# 401.070456591576

# %%
(720/z1)
# Out:
# 12.5663706143592

# %%
mu=n(pi)*4E-7;mu
# Out:
# 1.25663706143592e-6

# %%
(720/z1)/4
ç=(factorial(6)*z1);
# Out:
# 57.2957795130823

# %%
ai=int((1/deg(mu)/100))-1 #137 inverse alpha

# %%
a=round(deg(mu)*100,4) #alpha

# %% [markdown]
# show(LatexExpr(r"\alpha="),a," & : ",
#      LatexExpr(r" \alpha^{-1}= "),ai)

# %% [markdown]
# ##### Relativité et Quantique obsolescence programmée !
#
# Le monde, l'univers, l'espace sont purement géométriques ! Le reste c'est de la foirinette de l'enfumage intellectuel, dommageable pour l'esprit humain !
#
# Ré-écriture de la Science obsolète :
#
# $F_a = \frac{1}{\sqrt L C}$=ç=314159265 =chiracécité

# %%
deg(x)=x*180/n(pi);deg(zeta(221.0))
z1=deg(zeta(221.0));
mu=factorial(6)/z1*1E-7

# %%
mu=1/n(pi)*360E-8;ep=1/(n(pi)*360E+8)
ç=sqrt(1/(mu*ep));show(round(ç,8)," m/s")
# Out:
# 314159265.35897934 ' m/s'

# %%
ç=(factorial(6)/z1)/4*100000000
show(LatexExpr(r"ç^2= "),ç*ç)
# Out:
# ç^2=  9.86960440108936e16

# %%
zeta(2)
# Out:
# 1/6*pi^2

# %%
show(LatexExpr(r"ç=\frac{6!}{\zeta(0)}"))
# Out:
# ç=\frac{6!}{\zeta(0)}

# %%
ç=(factorial(6)/z1)/4*100000000;round(ç,8)
# Out:
# 314159265.3589793

# %%
mu=(1/n(pi)*factorial(6)/zeta(0)/-4)*1E-8

# %%
mu
# Out:
# 1.14591559026165e-6

# %%
epsilon=(1/(n(pi)*factorial(6)/zeta(0)/-4)*1E-8)

# %%
epsilon
# Out:
# 8.84194128288307e-12

# %%
round(sqrt(1/(mu*epsilon),)
# Out:
# 3.14159265358979e8

# %%
mu=(1/n(pi)*factorial(6)/zeta(0)/-4)*1E-8
show(LatexExpr(r"L=\mu=\frac{1}{\pi (6!)\zeta(0)}"))
# Out:
# L=\mu=\frac{1}{\pi (6!)\zeta(0)}

# %%
show(LatexExpr(r"mu=\frac{1}{\pi (6!)}{\frac{\zeta(0)"}}}))
# Out:
# mu=\frac{1}{\pi (6!)}{\frac{\zeta(0){}}}}

# %% [markdown]
# $mu=(1/n(pi)*factorial(6)/zeta(0)/-4)*1E-8$
