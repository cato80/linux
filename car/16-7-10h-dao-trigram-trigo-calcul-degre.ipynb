# %%
n(pi)/2
# Out:
# 1.57079632679490

# %%
L4=2*n(pi)*(90/360);
deg(x)=x*180/n(pi);
show(deg(500)," = ",L4)
# Out:
# 28647.8897565412 ' = ' 1.57079632679490

# %%
rad(x)=x*n(pi)/180;show(rad(25812.807))# Rk
# Out:
# 450.518471331840

# %%
L4=2*n(pi)*(45/360);
deg(x)=x*180/n(pi);
show(deg(45)," = ",L4)
# Out:
# 2578.31007808870 ' = ' 0.785398163397448

# %%
78628/25812.0# Rk
# Out:
# 3.04618007128467

# %%
# %display latex
var("y")
d=x;di=plot(d,x,-2,2,color="black")
dn=-x;ni=plot(dn,x,-2,2,color="orange")
d1=x/2.5;n1=plot(d1,x,-2.65,2.65,color="green")
d2=x*2.5;n2=plot(d2,x,-1.06,1.06,color="violet")
ce=circle((0,0),2.85,color="red")
ci=circle((0,0),2,color="black")
h = implicit_plot(x^2+y^2-8, (-3,3), (-3,3),plot_points=4)
show(h+ce+di+ni+n1+ni+n2+ci,figsize=4,axes=True,
aspect_ratio=1,gridlines="Minor",frame=False,fontsize=6)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
x1=plot(-x*1.886,-1.41,1.41,color="red")
x2=plot(x*1.886,-1.41,1.41,color="red")
op = polygon(((-1.77,-1.77),(-1.77,1.77),
              (1.77,1.77),(1.77,-1.77)),color="blue",
             edgecolor="red",thickness=1, alpha=0.3)
ca=circle((0,0),2,rgbcolor="red",
          thickness=2,fill="green",alpha=0.2)
ld=line(((-1.77,0),(1.77,0)), color="blue",thickness=1)
show(op+ca+x1+x2+ld,xmin=-2,xmax=2,ymin=-2,ymax=2,
     gridlines="minor",figsize=5,fontsize=8,
     gridlinesstyle=dict(color="lightgreen",linestyle="-"),
     frame=False,axes=True)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
show(ce+ci,
     xmin=-3,xmax=3,ymin=-3,ymax=3,
     gridlines="minor",figsize=5,fontsize=8,
     gridlinesstyle=dict(color="lightgreen",linestyle="-"),
     frame=False,axes=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a1 = arc((0,0), 2.85, angle=pi/4, 
sector=(pi/4,1*pi/-4),thickness=2)
a2 = arc((0,0), 2, angle=pi/6,color="red", 
sector=(pi/-6,0.9*pi/6),thickness=2)
a3 = arc((0,0), 2, angle=pi/2.45,color="green", 
sector=(pi/11,1*pi/-11),thickness=2)
show(ce+ci+a1+a2+a3,figsize=5,frame=True,fontsize=6)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
dr=x*pi/2;nr=plot(dr,x,-1.51,1.51,
color="black",linestyle="--")
show(ce+ci+a1+a2+a3+nr,
xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",figsize=5,fontsize=6,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=False,axes=True)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
po = polygon(((-1,-1),(-1,1),(1,1)  ,(1,-1)),color="orange",
edgecolor="red",thickness=1, alpha=0.3)
pa = polygon(((-2,-2),(-2,2),(2,2) ,(2,-2)),color="green",
edgecolor="red",thickness=1, alpha=0.2)
show(ce+ci+a1+a2+a3+nr+po+pa,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",figsize=5,fontsize=6,frame=False,axes=True,
gridlinesstyle=dict(color="cyan",alpha=0.2,linestyle="-"))
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
r=2/sqrt(n(pi));cc=circle((0,0),r,color="black")
show(ce+ci+cc+a1+a2+a3+nr+po+pa,xmin=-3,xmax=3,ymin=-3,ymax=3,
gridlines="minor",figsize=5,fontsize=6,frame=False,axes=True,
gridlinesstyle=dict(color="cyan",alpha=0.2,linestyle="-"))
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
dx=1.04719755119660;dy=1
p0=plot(x/0.571,x,0,1)
pt1 = point((1.048, 1.69), 
            rgbcolor="red", pointsize=50,)
pt2 = point((1.048, 1.69)
            , rgbcolor="white", pointsize=10)
l0 = line([(0, 1.69),(1.048, 1.69)], linestyle="--",color="red")
l1 = line([(1.048, 0),(1.048, 1.69)], linestyle="--",color="red")
show(ce+ci+a1+a2+a3+nr+pt1+pt2+l0+p0+l1,
gridlines="major",figsize=5,fontsize=6,frame=False,axes=True,
gridlinesstyle=dict(color="cyan",alpha=0.5,linestyle="-"))
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
deg(x)=x*180/n(pi);show(deg((sin(0.6))))
# Out:
# 32.3516306593634

# %%
57-36
# Out:
# 21

# %%
sin(0.62)
# Out:
# 0.581035160537305

# %%
cos(0.62)
# Out:
# 0.813878456662534

# %%
sin(0.2)+cos(0.5)
# Out:
# 1.07625189268543

# %%
sin(0.5)^2+cos(0.5)^2
# Out:
# 1.00000000000000

# %%
p0=plot(x/1.0,x,0,1);pt1=point((1.048,1.69),rgbcolor="red",
pointsize=50,);pt2=point((1.048,1.69),rgbcolor="white",pointsize=10)
l0 = line([(0, 1.69),(1.048, 1.69)], linestyle="--",color="red")
l1 = line([(1.048, 0),(1.048, 1.69)], linestyle="--",color="red")
show(ce+ci+a1+a2+a3+nr+pt1+pt2+l0+p0+l1,xmin=-3,xmax=3,ymin=-3,
ymax=3,gridlines="major",figsize=5,fontsize=6,frame=False,axes=True,
gridlinesstyle=dict(color="cyan",alpha=0.5,linestyle="-"))
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
L=2*n(pi)*1*(45/360);show(L)
# Out:
# 0.785398163397448

# %%
377/360.0
# Out:
# 1.04722222222222

# %%
factorial(6)
# Out:
# 720

# %%
L=2*n(pi)*1*(57.2957795130823/360);show(L)
# Out:
# 1.00000000000000

# %%
deg(x)=x*180/n(pi);
show(deg(0.285)," = ",L)
# Out:
# 16.3292971612285 ' = ' 1.00000000000000

# %%
cos(1.047),sin(1.6)
# Out:
# (0.500171074597070, 0.999573603041505)

# %%
integrate(cos(1.047)+sin(1.6),x,0,1)
# Out:
# 1.4997446776385752

# %%
62.8*135/360
# Out:
# 23.5500000000000

# %%
pl=plot(x/1,x,0,1);
l2 = line([(0, -1.69),(-1.048, -1.69)], linestyle="--",color="red")
l3 = line([(-1.048, 0),(-1.048, -1.69)], linestyle="--",color="red")
show(ce+ci+a1+a2+a3+nr+pt1+pt2+l0+pl+l1+l2+l3
,xmin=-3,xmax=3,ymin=-3,ymax=3,gridlines="major",figsize=5,
fontsize=6,frame=False,axes=True,
gridlinesstyle=dict(color="cyan",alpha=0.5,linestyle="-"))
# Out:
# Graphics object consisting of 13 graphics primitives

# %%
n(pi)/4
# Out:
# 0.785398163397448

# %%
n(pi)/3
# Out:
# 1.04719755119660

# %%
sqrt(3.0)
# Out:
# 1.73205080756888

# %%
n(pi)/6
# Out:
# 0.523598775598299

# %%
4.77^(-1/3)
# Out:
# 0.594055754260179

# %%
n(pi)/0.5
# Out:
# 6.28318530717959

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sin(n(pi)/2)+cos(n(pi)*2)
# Out:
# 2.00000000000000

# %%
cos(n(pi)*2)
# Out:
# 1.00000000000000
