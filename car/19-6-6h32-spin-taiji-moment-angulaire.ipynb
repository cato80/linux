# %%
# %display latex

# %% [markdown]
# ###### Ether
#
# L'éther du vide est l'impédance : C'est une force de résistance, donc en ohm ($\Omega$). Sa valeur est Z = 360 $\Omega$,($Z^2=129600$), donc un 1 ohm = 1 degré. On en déduit que le vide n'est pas vide = 0, puisqu'il est une impédance. Il y a 2 vide : vide=0 et vide=éther=360 $\Omega$

# %%
Inductance=1/(1/n(pi)*360E-8);L=Inductance
Capacitance=1/(1/(n(pi)*360E+8));C=Capacitance
show("L=",L," Volts");show("C=",C," Amperes")
show("Puissance=",L*C," Watts J/s")
# Out:
# 'L=' 872664.625997165 ' Volts'
# 'C=' 1.13097335529233e11 ' Amperes'
# 'Puissance=' 9.86960440108936e16 ' Watts J/s'

# %% [markdown]
# Les données peuvent être données en valeurs scientifiques, mais je pense que pour la démonstration il vaut mieux garder des données imaginaires, qui pourraient se révéler être plus exactes dans un temps futur que les valeurs actuelles.
#
# Je ne parle plus de célérité $c$ mais de fréquence angulaire $\omega$ = Fa.

# %%
Fa=L*C;show("1 coulomb=",round(Fa/1E8),"=",round(Fa/1E11)," tonnes")
# Out:
# '1 coulomb=' 986960440 '=' 986960 ' tonnes'

# %%
show("Fa=",Fa,"=c^2")
# Out:
# 'Fa=' 9.86960440108936e16 '=c^2'

# %%
show("Fa=coulomb=",Fa)
# Out:
# 'Fa=coulomb=' 9.86960440108936e16

# %%
plot(sqrt(x*abs(x))*sgn(-x),
     [x,-1,1],aspect_ratio=1,
     figsize=3,fontsize=5,fill=True)
# Out:
# verbose 0 (3791: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 100 points.
# verbose 0 (3791: plot.py, generate_plot_points) Last error message: 'math domain error'
# Graphics object consisting of 2 graphics primitives

# %%
def f(x):
    if x<0:return sqrt(-x^2-2*x)
    else:return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',
       fill=sqrt(4-x^2),fillcolor="black",alpha=0.1)
b=plot(f,(x,-2,2),color='white',
       fill=-sqrt(4-x^2),fillcolor="red",alpha=0.1)
show(a+b,figsize=2,axes=False,aspect_ratio=1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
s1=circle((1,0),1,color="salmon")
s2=circle((-1,0),1,color="grey")
s3=sphere(center=(0,0,0),size=0.5,color="red")
show(a+b+s1+s2,figsize=2,axes=False,aspect_ratio=1)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# L=moment angulaire (égale vecteur de poynting dans le cas de la lumière) L=$c^2$=ExH=P
#
# https://prmarchenry.blogspot.com/2014/03/spin.html

# %% [markdown]
# $\left\{\begin{matrix} k=4\pi ^{2}\cdot m\cdot \nu _{0}^{2}\\v=2\pi r\cdot \nu \end{matrix}\right.\Rightarrow \frac{m\cdot v^{2}}{r}=k\cdot r+e\cdot v\cdot B\Rightarrow \nu \approx \nu _{0}\pm \frac{e\cdot B}{4\pi m} $
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Pour le mouvement circulaire dans le plan xy, la composante y pouvait émettre une lumière selon la direction x, tandis que la composante selon x émettait selon la lumière selon y. Comme le champ magnétique accélère ici l'une des composantes et ralentit l'autre, on s'attend à observer 3 raies, toutes de polarisation linéaires.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Pour établir son principe d'exclusion il utilisa une idée d'Edmund Stoner et proposa fin 1924 d'associer à chaque état atomique, et non "orbite" comme le faisait Bohr ou Sommerfeld, 4 nombres quantiques |n, l, mL, mS> avec -l ≤ mL ≤ +l, le quatrième nombre quantique mS ne pouvant prendre que deux valeurs ±1/2.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Pondération du nombre décimal
#
# La constitution des particules n'a rien à voir avec un problème de masse ou de vitesse, elles existent par leur pondération décimale : L'inverse de leur rang décimal. $\pi$ est naturel dans le sens où on peut le déduire à partir des nombres.Le rapport entre 8 et 0.81 début et fin du décimal (seconde et tierce égale quinte).

# %%
8/0.81
# Out:
# 9.87654320987654

# %%
sqrt(8/0.81) # zéro 8 chiffres après la virgule
# Out:
# 3.14269680527354

# %%
(2^3)/(3^4)
# Out:
# 8/81

# %%
2*3.141592653  # zéro 8 chiffres après la virgule
# Out:
# 6.28318530600000

# %%
n(pi,digits=35)\
/100000000000000000000000
# Out:
# 3.1415926535897932384626433832795029e-23

# %%
314159265358979323846264338327950987654321/\
100000000000000000000000000000000000000000
# Out:
# 314159265358979323846264338327950987654321/100000000000000000000000000000000000000000

# %%
1/(5.0/10000000000000000000000000000000)
# Out:
# 2.00000000000000e30

# %%
1/(3.0/10000000000000000000000000000000)
# Out:
# 3.33333333333333e30

# %%
1/(-0.0/10000000000000000000000000000000)
# Out:
# -infinity

# %%
1/(-0.0/10)
# Out:
# -infinity

# %%
1/-0.0
# Out:
# -infinity

# %% [markdown]
# $\alpha =\frac{e^{2}}{2\epsilon _{0}hc}=\frac{1}{137,035999074(44)}$

# %% [markdown]
# Lorsque le couplage entre le moment angulaire orbital $\vec {L}$ et le moment angulaire de spin $\vec {S}$ est plus fort que le couplage avec le champ magnétique extérieur, le couplage spin-orbite domine et l'on peut considérer que le moment orbital total $\vec {J} = \vec {L} + \vec {S}$ effectue un mouvement de précession autour de la direction définie par le champ magnétique.

# %% [markdown]
# Toutefois, si le champ magnétique est suffisamment fort, il casse le couplage existant entre les moments cinétiques orbital et de spin, ce qui change l'allure du spectre en multiplets. C'est ce que l'on appelle l'effet Paschen-Back. Dans ce cas, les moments $\vec {L}$ et $\vec {S}$ se couplent chacun fortement au champ magnétique extérieur, ce qui fait que chaque vecteur effectue un mouvement de précession autour du champ indépendamment l'un de l'autre.
#
# ![image.png](attachment:image.png)

# %%
pr=plot(sqrt(-x^2+2*abs(x))*sgn(x),[x,-2,2],
color="blue",aspect_ratio=1,figsize=3,fontsize=10,
fill=True,fillcolor="red",tick_formatter=[1/10,1/10])
pl=plot(sqrt(-x^2+2*abs(x))*sgn(-x),[x,-2,2],
color="green",aspect_ratio=1,figsize=10,fontsize=20,
fill=True,fillcolor="yellow",tick_formatter=[1/10,1/10])
show(pr+pl,frame=True,gridlines="minor")
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
v=314159265
wo=v*v;wo
# Out:
# 98696043785340225

# %%
wr=1/(L*C);wr
# Out:
# 1.01321183642338e-17

# %%
c=299792458;wc=c*c;wc
# Out:
# 89875517873681764
