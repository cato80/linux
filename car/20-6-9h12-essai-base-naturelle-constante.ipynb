# %% [markdown]
# ##### Essai de base naturelle pour les constantes

# %% [markdown]
# Les physiciens ont dévelopé une très mauvaise habitude : Ils normalisent tout, ils ramènent tout à un, pour faciliter les calculs, mais ils passent à côté de la quintessence de la valeur naturelle des constantes.
#
# $\lambda=\frac{\frac{1}{\sqrt\mu\epsilon}}{\frac{1}{2\pi\sqrt\mu\epsilon}}$ = $\frac{c}{\nu}$=$2\pi$

# %%
# %display latex
var("lambda_0 mu epsilon c nu omega") 
lo=lambda_0==(1/sqrt(mu*epsilon)/ \
(1/(2*pi*sqrt(mu*epsilon))));lo
# Out:
# lambda_0 == 2*pi

# %%
lo=lambda_0==(1/sqrt(mu*epsilon)/ \
1/(2*pi*sqrt(mu*epsilon)));lo
# Out:
# lambda_0 == 1/2/(pi*epsilon*mu)

# %%
lo=lambda_0==1/(1/(sqrt(mu*epsilon))/ \
(1/2*pi*sqrt(mu*epsilon))^2);lo
# Out:
# lambda_0 == 1/4*pi^2*sqrt(epsilon*mu)*epsilon*mu

# %% [markdown]
# Il y a une constante de base $\pi$ (ça pourrait être autre chose, car après plusieurs calculs on retombe toujours sur les mêmes résultats ?). Mais j'aime bien $\pi$ qui possède tellement de mystère. J'en suis même arriver à la conclusion que le yin et yang était $\pi$ :
# un yin plus un yang égale un taiji :
# un $\pi$, plus un $\pi$ moins, égale un cercle
# Un pipi égale un bébé ! lol

# %%
round(2.54647908947033*25.1327412287183)
# Out:
# 64

# %% [markdown]
# Le but d'un rapport c'est de ne pas être infini. Ou l'inverse de calculer la limite du fini. D'ailleurs on ne devrait pas dire infini mais fini(+) ou fini(-) qui serait plus humble, que de parler d'infini comme si l'homme était infini ? L'esprit est infini parce-que le bon Dieu, mais l'homme est mortel justement pour lui éviter de se prendre la tête et de se prendre pour Dieu, on voit bien aujourd'hui que malgré la mortabilité, les puissants cherchent à se faire croire immortels ! Quel arrogance d'appeler des gens "Les immortels" et surtout quelle hypocrisie, qui va d'ailleurs de pair avec l'auto suffisance !

# %%
p1=arc((0,0),2,angle=pi/6,sector=(pi/4,5*pi/6))
p2=line(((0,0),(2*cos(pi/6),2*sin(pi/6))),
color="red",linestyle="dashed")
p3=line(((0,0),(2*cos(pi/6+pi/2),2*sin(pi/6+pi/2))),
color="red", linestyle="dashed")
p4=circle((0,0),2,color="red",zorder=-5);p1+p2+p3+p4
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
p1=circle((0,0),2)
p2 = arrow((0,0),(2*cos(pi/6),2*sin(pi/6)),
linestyle="dashed", color="red")
p3 = arrow((0,0),(2*cos(pi/6+pi/2),2*sin(pi/6+pi/2)),
           linestyle="dashed");p1=circle((0,0),2)
p2 = arrow((0,0),(2*cos(pi/6),2*sin(pi/6)),
linestyle="dashed", color="red")
p3 = arrow((0,0),(2*cos(pi/6+pi/2),
2*sin(pi/6+pi/2)),linestyle="dashed", color="red")
p4=arc((0,0),2,angle=pi/6,sector=(0,pi/2),
color="red",thickness=2, zorder=5);

p4=arc((0,0),2,angle=pi/6,sector=(0,pi/2),
color="red",thickness=2, zorder=5);
show(p1+p2+p3+p4,figsize=3)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
p1=circle((0,0),1)
p2 = arrow((0,0),(cos(pi/8),sin(pi)),
linestyle="dashed", color="red",width=1,arrowsize=1.5)
p3 = arrow((0,0),(cos(pi/4),sin(pi/2)),
linestyle="dashed", color="red",width=1,arrowsize=1.5)
p4=arc((0,0),1,angle=2*pi/6,sector=(0,-pi/3),
color="red",thickness=1, zorder=5);
x1=x;a=plot()
show(p1+p2+p3+p4,figsize=5,fontsize=4,gridlines="minor",
gridlinesstyle=dict(color="orange",linestyle="-",
alpha=0.5))
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
deg(x)=x*180/n(pi);show(deg((0.8414710)))
# Out:
# 48.2127368826529

# %%
p1=circle((0,0),1,color="green")
p3 = arrow((0,0),(cos(pi/3),2*sin(pi/7)),
linestyle="dashed", color="red",width=1,arrowsize=1.5)
p2 = arrow((0,0),(cos(pi/32),sin(pi)),
linestyle="dashed", color="red",width=1,arrowsize=1.5)
s=plot(sin(2*x),x,0,0.51)
p4=arc((0,0),1,angle=2*pi/6,sector=(0,-pi/3),
color="red",thickness=1, zorder=5);
show(p1+p2+p3+p4+s,figsize=5,fontsize=4,gridlines="minor",
gridlinesstyle=dict(color="orange",linestyle="-",
alpha=0.2),frame=True,axes=False)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
lb=line([(0,0),(0.5,0.841)],color="black",linestyle=":");
r=2/sqrt(n(pi));rs=1/sqrt(2.0)
rc=r/1.33;r=2/sqrt(n(pi))
cb=circle((0,0),rs,color="brown")
cr= circle((0,0),rc,color="red")
cg= circle((0,0),1,color="green")
show(cg+lb+s,gridlines="minor",
gridlinesstyle=dict(color="orange",linestyle="-",
alpha=0.5),figsize=5,axes=True,frame=True,fontsize=5)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
n(pi*2)/6
# Out:
# 1.04719755119660

# %%
(314159265.3/299792458)*n(pi*2)
# Out:
# 6.58429132279003

# %%
deg(x)=x*180/n(pi);show(deg((0.8414710)))
# Out:
# 48.2127368826529

# %% [markdown]
# En accord avec la dualité onde-corpuscule de Louis de Broglie, pour que ce modèle soit viable, il faut que la longueur d'onde associée au photon λ soit égale à la circonférence de l'anneau 2πR, soit: $\lambda = \frac{c}{\nu} = 2\pi R \Rightarrow R = \frac{c}{2\pi \nu}$
# Le moment angulaire étant égal au produit de la quantité de mouvement p = E/c par la distance à l'axe de rotation R, il vient:
#
# $S = \frac{E}{c}\cdot R = \frac{h\nu}{c}\cdot \frac{c}{2\pi \nu} \Rightarrow L
# = \frac{h}{2\pi} = \hbar$
#
# Le photon est donc bien une particule de spin entier égal à ħ. Selon les lois gouvernant le moment angulaire en physique quantique, le photon peut donc exister sous trois états de polarisation $S z = {-ħ, 0, +ħ}$.
#
# 1) L'état $S z = -ħ$ =
#
# $\hat S_z\left|-1\right> = -\hbar \left|-1\right>$
#
# 2) $S z = +ħ$
#
# $\hat S_z\left|+1\right> = +\hbar \left|+1\right>$
#
# 3)
# $\hat S_z\left|0\right> = 0$

# %%
R=299792458/(2*n(pi));R
# Out:
# 4.77134515923694e7

# %%
fr=1/(2*n(pi)*sqrt(299792458.0));fr
# Out:
# 9.19199501550972e-6

# %%
299792458/(2*3.1415)
# Out:
# 4.77148588254019e7

# %% [markdown]
# Le spin égale le taiji = -1($-\hbar$) 0 +1($+\hbar$)
#
# +0- Trinaire balancé
#
#
# $q=\frac{E}{c}$  quantité de mouvement

# %%
q=1.0/299792458;q # n= indice de réfraction
# Out:
# 3.33564095198152e-9

# %% [markdown]
# Correspond à l'indice de réfraction $n= \sqrt\mu \epsilon$
#
# puisque $c=\frac{1} {\sqrt\mu \epsilon}$

# %%
deg(x)=x*180/n(pi);show(deg(1))
360/57.2957795130823 # 2 pi
# Out:
# 57.2957795130823
# 6.28318530717959

# %%
n(pi*2)
# Out:
# 6.28318530717959

# %%
6.28318530717959*60
# Out:
# 376.991118430775

# %%
6.28318530717959*60
# Out:
# 376.991118430775

# %%
120*3.1426
# Out:
# 377.112000000000

# %%
sqrt(9.8765432)*120
# Out:
# 377.123616444264

# %%
14400*9.87
# Out:
# 142128.000000000

# %%
377*377
# Out:
# 142129

# %%
(120*3.141592653)^2
# Out:
# 142122.303322324

# %%
377^2
# Out:
# 142129

# %%
314159.265-299792.458
# Out:
# 14366.8070000000

# %%
14366.807/3.141592653
# Out:
# 4573.09670185303

# %%
u=1/n(pi)*360E+8;u
# Out:
# 1.14591559026165e10

# %%
s=1/(n(pi)*360E-8);s
# Out:
# 88419.4128288308

# %%
1/(u*s)
# Out:
# 9.86960440108936e-16

# %%
sqrt(1/(u*s))
# Out:
# 3.14159265358979e-8
