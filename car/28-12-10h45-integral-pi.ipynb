# %% [markdown]
# ##### Calcul du rayon classique de l'électron
#
# $r_e=\frac{1}{4\pi \epsilon_0}$ $\frac{e^2}{m c^2}$ = $2.817940325 \times 10^{-15} m$
#
# Le premier rapport est $k$ coefficient de Coulomb.

# %%
mu=4*3.141592653E-7;c=299792458;ep=1/(mu*c*c)
e=1.60E-19;m=9.10E-31;k=1/(ep*(mu/1E-7))
Re=(1/k)*(e^2/m*c^2);Re=2.817940E-15

# %% [markdown]
# ###### Constante de Hubble

# %%
a=1/137.0;B=3-sqrt(5.0);pars=96939420213600000000/n(pi)
H0=(c*(a^19)*(sqrt(B)))/Re;Hu=H0*(pars)
show(LatexExpr(r"H_0=\frac{c a^{19} \sqrt B}{r_e}="),H0,"m")
show(LatexExpr(r"H_0\frac{MParsec}{1000}="),Hu," km/s");
# Out:
# /home/pi/.local/lib/python3.8/site-packages/sympy/core/function.py:107: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   evalargspec = inspect.getargspec(cls.eval)
# H_0=\frac{c a^{19} \sqrt B}{r_e}= 2.34814841311843e-18 'm'
# H_0\frac{MParsec}{1000}= 72.4562891637406 ' km/s'

# %%
Me=m;1/a^20 #postulat 2 page 18
# Out:
# 5.42514491120474e42

# %%
G=((c^2)*Re*(a^20))/(Me*B);G
# Out:
# 6.71530429699786e-11

# %%
h=6.626;hb=h/6.28;
a/sqrt(B)*(H0*(hb^2)/G*c)^(1/3)
# Out:
# 0.0189426230321693

# %%
a=314159265.3;x=299792458
a*sqrt(1-(x/a)^2)
# Out:
# 9.39176559553849e7

# %%
sqrt(a^2-x^2)
# Out:
# 9.39176559553848e7

# %% [markdown]
# quel que soit le rayon du cercle que l’on prend, le rapport entre son périmètre et son diamètre est constant, mais pas infini!

# %%
# %display latex
r=2/sqrt(pi);r
# Out:
# 2/sqrt(pi)

# %%
n(r)
# Out:
# 1.12837916709551

# %%
8/8.1
# Out:
# 0.987654320987654

# %% [markdown]
# Je recherche la pondération décimale de zéro et sa position : $r$ a un zéro à la 10 position
#
# 1.128379167-0
#
# Dans la fraction zéro est en 9ième position. La racine carrée de la fraction est $\pi$ au centième exacte.

# %%
f=0.987654320987654*10

# %%
sqrt(f)
# Out:
# 3.14269680527354

# %% [markdown]
# Normalement $\pi$ à un zéro (c'est-à-dire une racine) à la 32 ième décimale. Je dis que base et racine est la même chose, base 10 et racine de 10 sont équivalent. C'est une fréquence de résonance. Une racine est un couplage (particule,cellulle) , ici, [0,1]

# %%
sqrt(9.876543210)
# Out:
# 3.14269680529319

# %% [markdown]
# Entre les 9 et dix chiffres, le résultat ne varie qu'à la 11 ième décimale de 7354 on a 9319

# %%
9319.0/7354.0
# Out:
# 1.26720152298069

# %%
7354.0/9319.0
# Out:
# 0.789140465715205

# %%
(1/7354.0)/(1/9319.0)
# Out:
# 1.26720152298069

# %%
u(n) = n^100 / 100^n
u(2.);u(3.);u(4.);u(5.);u(6.);u(7.);u(8.);u(9.);u(10.);

# %%
p=plot(u(x), x, 0, 40)

# %%
x=0
f(x)=sqrt(r^2-x^2);f(1)
