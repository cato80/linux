# %%
c=299792458;ç=314159265.3

# %%
show(LatexExpr(r"L=L_o\sqrt 1 - \frac{c^2}{ç^2}"))
# Out:
# L=L_o\sqrt 1 - \frac{c^2}{ç^2}

# %%
l=ç*sqrt(1-(c^2/ç^2))
show(LatexExpr(r"L=L_o\sqrt 1 - \frac{c^2}{ç^2}"))
# Out:
# L=L_o\sqrt 1 - \frac{c^2}{ç^2}

# %% [markdown]
# La contraction ne se fait que dans un sens, alors qu'elle devrait être dans les 2 sens et produire ainsi une compression, les particules sont compressées selon la vitesse transversale (c) et axiale (ç verticale). Une particule est une onde compressée.En musique c'est l'intervalle (l'onde) et la note (la particule).
#
# Une note est la somme d'un bémol $\flat$  et d'un diéze $\sharp$, leur centre, leur inertie.

# %%
h
