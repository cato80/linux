# %%
# %display latex
h=6.626E-34;hb=h/(2*n(pi));hb
# Out:
# 1.05456065292690e-34

# %%
hb/2
# Out:
# 5.27280326463449e-35

# %%
H=n(pi)*2E-34;H
# Out:
# 6.28318530717959e-34

# %%
Hb=H/(2*n(pi));Hb
# Out:
# 1.00000000000000e-34

# %%
Hb/2
# Out:
# 5.00000000000000e-35

# %%
var("c w m f h mu epsilon")
# Out:
# (c, w, m, f, h, mu, epsilon)

# %%
c=2*pi*f;hb=h/2*pi;w=2*pi*f;w
# Out:
# 2*pi*f

# %%
R=c/w

# %%
l=hb/m*c

# %%
l
# Out:
# pi^2*f*h/m

# %%
solve(l==R,f)
# Out:
# [f == m/(pi^2*h)]

# %%
solve(l==R,h)
# Out:
# [h == m/(pi^2*f)]

# %%
solve(l==R,m)
# Out:
# [m == pi^2*f*h]

# %%
solve(l==R,pi)
# Out:
# [pi == -sqrt(m/(f*h)), pi == sqrt(m/(f*h))]

# %%
solve(l==R,)
# Out:
# []

# %%
c=1/sqrt(mu*epsilon);c
# Out:
# 1/sqrt(epsilon*mu)

# %%
w==c
# Out:
# 2*pi*f == 1/sqrt(epsilon*mu)

# %%
fr=1/(2*pi*sqrt(mu*epsilon));fr
# Out:
# 1/2/(pi*sqrt(epsilon*mu))

# %%
solve(fr==w,f)
# Out:
# [f == 1/4/(pi^2*sqrt(epsilon*mu))]

# %%
solve(fr==w,pi)
# Out:
# [pi == -1/2*sqrt(1/(sqrt(epsilon*mu)*f)), pi == 1/2*sqrt(1/(sqrt(epsilon*mu)*f))]

# %%
assume(f>0)
solve(fr==w,mu)
# Out:
# [mu == 1/16/(pi^4*epsilon*f^2)]

# %%
assume(f>0)
solve(fr==w,epsilon)
# Out:
# [epsilon == 1/16/(pi^4*f^2*mu)]

# %%
solve(fr==f,epsilon)
# Out:
# [epsilon == 1/4/(pi^2*f^2*mu)]

# %%
solve(fr==f,mu)
# Out:
# [mu == 1/4/(pi^2*epsilon*f^2)]

# %%
c/fr
# Out:
# 2*pi

# %%
show(LatexExpr(r""))
# Out:
# \begin{math}
# \newcommand{\Bold}[1]{\mathbf{#1}}
# \end{math}

# %%
fc=1/((2*n(pi))/299792548);fc
# Out:
# 4.77134659163143e7

# %%
T=((2*n(pi))/299792548);T
# Out:
# 2.09584439276309e-8

# %%
T*fc
# Out:
# 1.00000000000000

# %%
mu*epsilon*c
# Out:
# epsilon*mu/sqrt(epsilon*mu)

# %%
mu*epsilon*c^2
# Out:
# 1

# %%
(mu*epsilon*c)
# Out:
# epsilon*mu/sqrt(epsilon*mu)

# %%
2*n(pi)/60
# Out:
# 0.104719755119660

# %%
314159265.3/299792548
# Out:
# 1.04792219618481

# %%
deg(x)=x*180/n(pi);deg(1.04719755119660)
# Out:
# 60.0000000000001

# %%
deg(x)=x*180/n(pi);deg(1.04792219618481)
# Out:
# 60.0415190994699

# %%
v= 2*n(pi)*10000000;v/(2*n(pi))
# Out:
# 1.00000000000000e7

# %%
299792548/(2*n(pi))
# Out:
# 4.77134659163143e7
