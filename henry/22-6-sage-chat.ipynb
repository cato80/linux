# %% [markdown]
# ##### sage-chat
#
# Quelques lignes intérêssantes page 36 : limites page 37 et chat page 45
#
# • limite x→a + :
#
# f(x) est la valeur y approchée par f lorsque x approche a de la droite (c'est-à-dire de nombres supérieurs à a)
# • limite x→a − :
#
# f (x) est la valeur y approchée par f lorsque x s'approche de a à partir de la gauche
#
#
# • limite x→a :
#
# f (x) est la valeur y approchée par f lorsque x approche a des deux côtés.

# %%
# %display latex
f(x)=x^2+1;p=plot(f,x,-2,2);f(x)
# Out:
# x^2 + 1

# %%
show(p,frame=True,figsize=3,fontsize=5,gridlines="major",aspect_ratio=1)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/backend_bases.py:57: DeprecationWarning: PILLOW_VERSION is deprecated and will be removed in Pillow 9 (2022-01-02). Use __version__ instead.
#   from PIL import PILLOW_VERSION
# Graphics object consisting of 1 graphics primitive

# %%
q=plot(x^2,x,-2,2)

# %%
show(q,frame=True,figsize=3,fontsize=5,gridlines="major",aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
limit(f(x), x=1),f(1),f(0)
# Out:
# (2, 2, 1)

# %%
limit((x^2 - 1)/(x - 1), x=1)
# Out:
# 2

# %%
limit(x/abs(x), x=0)
# Out:
# und

# %%
limit(x/abs(x), x=0, dir='left')
# Out:
# -1

# %%
limit(1/x, x=0, dir='left')
# Out:
# -Infinity

# %%
limit(1/x, x=0, dir='right')
# Out:
# +Infinity

# %%
limit(sin(1/x), x=0)
# Out:
# ind

# %%
limit(1/x, x=0) == unsigned_infinity
# Out:
# Infinity == Infinity

# %% [markdown]
# Dérivés : Rappelons que la dérivée de f (x) à x = a est
#
# • la pente de la droite tangente à f (x) en x = a (si une telle droite existe) ; ou équivalent,
#
# • la limite des pentes des lignes sécantes reliant f en x = a et x = b, comme b → a ; ou alors,de manière équivalente,
#
# • la limite des pentes des lignes sécantes reliant f en x = a et x = b, comme la distance  entre a et b tend vers 0 ( ∆ x → 0); ou équivalent.
#
# • limite : Δ x → 0 f (a + ∆ x)− f (a) Δ x
#
# On peut aussi parler de la dérivée en tant que fonction ; c'est-à-dire que f (x) est
#
# • la valeur de f (a) lorsque x = a ; ou équivalent,
#
# • limite : Δ x → 0 : f (x + ∆ x)− f (x) : Δ x
#
# Les fonctions diff() et dérivé() de Sage calculent la dérivée en tant que fonction ; si tu veux calculer la dérivée en un point, définir une fonction et substituer.

# %%
diff(x^2,x)
# Out:
# 2*x

# %%
df(x) = diff(x^2, x);df(1)
# Out:
# 2

# %%
diff(cos(x), x, 1042)
# Out:
# -cos(x)
