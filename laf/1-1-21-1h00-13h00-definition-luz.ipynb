# %%
# %display latex 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# La longueur d'onde fondamentale est $2 \pi$

# %%
c=299792458.0
ic=0.00000000333564095198152

# %%
ç=314159265.3
iv=0.00000000318309886243549

# %%
ic/iv
# Out:
# 1.04792251077911

# %%
n(pi)/3
# Out:
# 1.04719755119660

# %%
ç/c
# Out:
# 1.04792251077911

# %% [markdown]
# L’indice $n$ dépend de la longueur d’onde de la lumière qui traverse le milieu ; d’une
# manière générale, lorsque la longueur d’onde diminue, l’indice augmente. On appelle
# ce phénomène la dispersion optique
# $n^2$= l'inverse de la célérité au carré

# %%
deg(x)=x*180/n(pi);deg(ç/c)
# Out:
# 60.0415371243953

# %%
deg(n(pi)/29.)
# Out:
# 6.14334470989761

# %%
# Out:
# 2.40748490551058

# %%
rad(x)=x*n(pi)/180;rad(98.765432)
# Out:
# 1.72378197555457

# %%
c*c
# Out:
# 8.98755178736818e16

# %%
f=(2*n(pi))/(2*n(pi));int(f)
# Out:
# 1

# %%
w=(314159265.3^2)/314159265.3;w
# Out:
# 3.14159265300000e8

# %%
lo=0.0005;d=0.1;lo/d
# Out:
# 0.00500000000000000

# %%
deg(0.005)
# Out:
# 0.286478897565412

# %%
rad(0.0072)
# Out:
# 0.000125663706143592

# %%
deg(0.0072)
# Out:
# 0.412529612494193

# %%
rad(1/0.007297352566417)
# Out:
# 2.39172937871534

# %%
deg(2.39172937871534)
# Out:
# 137.035999137835

# %%
360*1.04792251077911
# Out:
# 377.252103880480

# %%
360*1.04719755119660
# Out:
# 376.991118430776

# %%
Z=376.730

# %%
c*(n(pi)*4E-7)
# Out:
# 376.730313461771

# %%
376.730313461771/n(pi)
# Out:
# 119.916983200000
