# %%
p=plot(sqrt(1-x^2),x,0,1);
lh=line([(0,0),(0.5,0.859)],color="green")
lb=line([(0,0),(0.859,0.5)],color="green")
lm=line([(0,0),(0.7,0.7)],color="red")
show(p+lb+lh+lm,aspect_ratio=1,gridlines="minor",
figsize=5,fontsize=5);
# Out:
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2327: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   x_formatter = OldScalarFormatter()
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2352: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   y_formatter = OldScalarFormatter()
# Graphics object consisting of 4 graphics primitives

# %%
var("y")
# %display latex
f=x^2+y^2==sqrt(1-x^2)

# %%
lb=line([(0,0),(0.5,0.85)],color="green")
cg= circle((0,0),1,color="black")
l1=line([(0,0),(0.5,-0.85)],color="red")
l2=line([(0,0),(-1,0)],color="blue");
params=dict(figsize=3,axes=False,fontsize=1,
frame=True,gridlines="major",gridlinesstyle=\
dict(color="salmon",linestyle="-",alpha=0.3))
show(cg+lb+l1+l2,**params);
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
deg(x)=x*180/n(pi);deg(0.523598775598299)
# Out:
# 30.0000000000000

# %%
n(pi)/6
# Out:
# 0.523598775598299

# %%
deg(1/50.0)
# Out:
# 1.14591559026165

# %%
mu=4E-7*n(pi);mu
# Out:
# 1.25663706143592e-6

# %%
L=1/n(pi)*360E-8;L
# Out:
# 1.14591559026165e-6

# %%
rad(x)=x*n(pi)/180;rad(1.14591559026165)
# Out:
# 0.0200000000000001

# %%
rad(x)=x*n(pi)/180;rad(1.14591559026165E-6)
# Out:
# 2.00000000000001e-8

# %%
rad(1.25663706143592E-6)
# Out:
# 2.19324542246431e-8

# %%
C=1/(n(pi)*360E+8);C
# Out:
# 8.84194128288307e-12

# %%
RC=rad(8.84194128288307E-12);RC # C epsilon inverse
# Out:
# 1.54320987654321e-13

# %%
c=299792458;ep=1/(mu*c*c);ep
# Out:
# 8.85418781762039e-12

# %%
rc=rad(ep);rc
# Out:
# 1.54534730007447e-13

# %%
irc=1/rc;irc
# Out:
# 6.47103728690509e12

# %%
IRC=1/RC;IRC
# Out:
# 6.48000000000000e12

# %%
IRC/irc
# Out:
# 1.00138505044826

# %%
params=dict(figsize=5,axes=False,fontsize=5,
frame=True,gridlines="minor",gridlinesstyle=\
dict(color="salmon",linestyle="-",alpha=0.3))
show(cg+lb+l1+l2,**params);
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
hl=line([(0.5,0.86),(0.5,-0.86)],color="green")
show(cg+lb+l1+l2+hl,**params);
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
bl=line([(-1,-0.0),(0.5,-0.86)],color="red")
show(cg+lb+l1+l2+hl+bl,**params);
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
ml=line([(-1,0.0),(0.5,0.86)],color="blue")
show(cg+lb+l1+l2+hl+bl+ml,**params);
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
r=2/sqrt(n(pi));c=circle((0,0),2);
def f(x):
    if x<0:return sqrt(-x^2-2*x)
    else:return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="grey",alpha=0.9,linestyle="--")
b=plot(f,(x,-2,2),color='white',fill=-sqrt(4-x^2),
fillcolor="lightgray",alpha=0.9)
a1= arc((0,0), 2, angle=pi/2, sector=(1.6,1.5*pi),
color="red",thickness=1,linestyle="--")
show(a+b+cg+lb+l1+l2+hl+bl+ml,figsize=5,axes=False,fontsize=6,
aspect_ratio=1)
# Out:
# Graphics object consisting of 11 graphics primitives
