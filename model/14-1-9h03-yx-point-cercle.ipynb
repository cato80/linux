# %%
# %display latex
import warnings;warnings.filterwarnings(
"ignore",category=DeprecationWarning)

# %% [markdown]
# https://journals.openedition.org/bibnum/741

# %%
from sage.plot.point import Point
p=point([(0,0),(1,1)],color="green")
#P = Point([1,2],[2,3],{'alpha':.5})
c=plot(sqrt(1-x^2),x,-1,1);
show(c+p,aspect_ratio=1,gridlines="minor",
     figsize=5,fontsize=5);
# Out:
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2327: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   x_formatter = OldScalarFormatter()
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2352: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   y_formatter = OldScalarFormatter()
# Graphics object consisting of 2 graphics primitives

# %%
a=point([cos(1), sin(0.905)],color="red")
show(c+p+a,aspect_ratio=1,gridlines="minor",
     figsize=5,fontsize=5);
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
deg(x)=x*180/n(pi);deg(sin(0.9050001))
# Out:
# 45.0588458207875

# %%
b=point([cos(1), sin(0.905)],color="red")
show(c+p+b,aspect_ratio=1,gridlines="minor",
     figsize=5,fontsize=5);
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
x=0+1*-cos(10.0);x
# Out:
# 0.839071529076452

# %%
ce=circle((0,0),1,color="blue");ce
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p=point([(0,0),(0.705,0.705)],color="red")
show(ce+p,gridlines="minor",figsize=5)
deg(0.705)
# Out:
# Graphics object consisting of 2 graphics primitives
# 40.3935245567230
