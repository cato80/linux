# %% [markdown]
# ###### Relativité et quantique obsolescence programmée

# %%
# %display latex # (4)
c=299792458;a=7.2973525664E-3;Me=9.10938356E-31
h=6.626E-34;hb=h/(2*n(pi));hb=h/(n(pi)*2);
G=6.67322E-11;Lp=sqrt(hb*G/2*n(pi)*c^3);B=(3-sqrt(5.0))
mu=4*3.141592653E-7;c=299792458;ep=1/(mu*c*c)
e=1.60E-19;m=9.10E-31;k=1/(ep*(mu/1E-7))
Re=(1/k)*(e^2/m*c^2);Re=2.817940E-15
# Out:
# /home/pi/.local/lib/python3.8/site-packages/sympy/core/function.py:107: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   evalargspec = inspect.getargspec(cls.eval)

# %%
F=G/2*n(pi);F
# Out:
# 1.04822694638942e-10

# %%
Fc=G/(n(pi)^2);Fc
# Out:
# 6.76138549105721e-12

# %% [markdown]
# Le vide (l'espace) n'est pas vide=0, puisqu'il a pour valeur électronique, Z, impédance du vide.
#
# Trop d'erreurs se sont glissées dans ces théories, la première est la vitesse de la lumière $c$ qui n'est pas une vitesse mais une Fa=Fréquence angulaire (note fondamentale).

# %%
show(LatexExpr(r"Fa=ç=\frac{1}{\sqrt \alpha \omega}"))
# Out:
# Fa=ç=\frac{1}{\sqrt \alpha \omega}

# %%
u=1/n(pi)*360E-8;u
# Out:
# 1.14591559026165e-6

# %%
s=1/(n(pi)*360E+8);s
# Out:
# 8.84194128288307e-12

# %%
ç=1/sqrt(u*s);ç
# Out:
# 3.14159265358979e8
