# %%
r=1
f=sqrt(r^2-x^2)

# %%
g=plot(f,x,0,1,thickness=1/2)

# %%
show(g,aspect_ratio=1,figsize=3,fontsize=5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# %display latex
integral(f,x,0,1)
# Out:
# 1/4*pi

# %%
r*sqrt(1-(x/r))^2
# Out:
# -x + 1

# %%
yi=1/(x^2+1);ys=1/(2*x);y=(1/2*x)/(pi/2);ya=1/(pi*x)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
