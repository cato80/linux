# %% [markdown]
# ###### Si Coulomb avait su !
#
# En mesurant la charge élémentaire, il aurait pu découvrir le poids d'un photon (force, énergie) mais Maxwell n'était pas encore passé !
#
# ![image.png](attachment:image.png)
#
# Le Coulomb égale 9000000000 Newtons soit près de neuf cent mille tonnes ! 10 N environ = 1 kg
#
# S'il avait pu mesurer 89875517873681764 ($c^2$) en Newton, c'est à dire descendre à 1E-7, il aurait obtenu le poids la force en Newton de la lumière et son poids en Peta tonnes = 90 Pt

# %%
c=299792458;cc=c^2;cc #17chiffres 898 Peta Newton
# Out:
# 89875517873681764

# %%
cc/1E15 # 15 chiffres 89.8755178736818 Peta Tonne
# Out:
# 89.8755178736818

# %%
show(LatexExpr(r"c^2=\frac{1}{4\pi\epsilon_0}\frac{1}{10^{-7}}={89875517873681764}"))
# Out:
# c^2=\frac{1}{4\pi\epsilon_0}\frac{1}{10^{-7}}={89875517873681764}

# %%
show(LatexExpr(r"\alpha=\frac{1}{4\pi\epsilon_0}\frac{e^2}{\hbar c}=\frac{1}{137}"))
# Out:
# \alpha=\frac{1}{4\pi\epsilon_0}\frac{e^2}{\hbar c}=\frac{1}{137}

# %%
1/(n(pi)*4) # alpha 0.0072 ?
# Out:
# 0.0795774715459477

# %%
mu=4E-7*n(pi);ep=1/(mu*c*c);ec=1.602E-19
h=6.626E-34;hb=h/2*n(pi)

# %%
a=1/(mu*ep);(ec^2)/(hb*c)
# Out:
# 8.22494517948058e-14

# %% [markdown]
# si des lois de la physique sont invariantes par symétrie par rapport à 1' origine, elles le sont par réflexion par rapport à un plan. En d'autres termes l'objet et son image dans un miroir sont superposables (mais décalée).

# %%
# %display latex
r=2/sqrt(n(pi));c=circle((0,0),2);
def f(x):
    if x<0:return sqrt(-x^2-2*x)
    else:return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',fill=sqrt(4-x^2),
fillcolor="lightgrey",alpha=0.1)
b=plot(f,(x,-2,2),color='lightsalmon',
fill=-sqrt(4-x^2),fillcolor="lightsalmon",alpha=0.1)
c=show(a+b,figsize=3,axes=False,fontsize=6,aspect_ratio=1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
lb=line([(0,0),(1.2,1.2)],color="black",linestyle=":");
rs=1/sqrt(2.0)
rc=zeta(2.0);r=2/sqrt(n(pi))
ca=circle((0,0),2,color="black")
cb=circle((0,0),1.7,color="green")
cr= circle((0,0),r/1.33,color="red")
cg= circle((0,0),r,color="brown")
cz= circle((0,0),sqrt(2),color="blue")
cy= circle((0,0),0.57,color="violet")
cx= circle((0,0),0.28,color="black")
#cv= circle((0,0),0.28,color="brown")
d3=line([(-1,-1),(-1,1),(1,1)],color="black",
linestyle="-");d4=line([(1,1),(1,-1),(-1,-1)],
color="black",linestyle="-")
show(ca+cg+lb+cr+cz+cy+cx+cb+d3+d4+a+b,gridlines="minor",
gridlinesstyle=dict(color="orange",linestyle="-",
alpha=0.2),figsize=5,axes=True,frame=True,fontsize=5)
# Out:
# Graphics object consisting of 14 graphics primitives

# %% [markdown]
# Le Taiqi est chiral = ç = chiracécité

# %% [markdown]
# C'est faux! Car la lumière n'est pas une vitesse (c'est une pulsation) donc elle peut être dépassée.
#
# La théorie quantique des champs est la généralisation de la mécanique quantique
# pour tenir compte de la relativité restreinte. El1e permet de décrire les particules
# élémentaires. Elle est basée sur le principe de causalité qui signifie que la cause
# doit précéder les effets, et sur le fait qu' il n'est pas possible d'avoir une action
# instantanée à distance (on ne peut dépasser la vitesse de la lumière dans le vide).
# Cette théorie prévoit que les particules de spin demi-entier, les fennions, obéissent
# à la statistique de Fermi-Dirac et donc au principe d' exclusion de Pauli.

# %% [markdown]
# Une nouvelle erreur le vide n'est pas vide = 0, il a une impédance de 376 $\Omega$

# %%
76.0^(-1/3)
# Out:
# 0.236081597854342

# %%
1.7*8#v eV ?
# Out:
# 13.6000000000000

# %%
a=0.007297352566417

# %%
1/a
# Out:
# 1.00000000000000

# %%
0.007297352566417*(1/0.007297352566417)
# Out:
# 1.00000000000000

# %%
0.007297352566417*137.0359991378354
# Out:
# 1.00000000000000

# %%
1/0.007297352566417
# Out:
# 137.035999137835

# %%
k=round(8.9875517873681764E9);k
# Out:
# 8987551787

# %%
k/(1/0.007297352566417)
# Out:
# 6.55853340986701e7
