# %%
# %display latex
hb=var('hbar',latex_name='\hbar')
nb=var("nabla",latex_name=r"\nabla");show(nb,hb)
print u"\u00E7","= 314159265"
# Out:
# nabla hbar
# ç = 314159265

# %% [markdown]
# ###### Equation inachevé de Maxwell
#
# L'équation locale de Maxwell est une équation inachevée, car elle aurait du être finie par changement de variable
#
# $\vec\nabla\cdot\vec E=\frac{\rho}{\epsilon}$
#
# devrait être
#
# $\vec\nabla\cdot\vec E=\frac{\mu}{\epsilon}=Z=360\Omega$
#
# $ç$ est le pendant de la célérité, car la lumière n'est pas une vitesse, mais une fréquence angulaire.
#
# $\omega= \frac{1}{\sqrt\mu \epsilon}=314159265$

# %%
Z=360
u=var("mu",latex_name="\mu")
s=var("epsilon",latex_name=r"\epsilon")

# %%
Z0=Z=sqrt(mu/epsilon);show("Z=",Z0,"= 360 Ohms")
# Out:
# 'Z=' sqrt(mu/epsilon) '= 360 Ohms'

# %%
u=1/n(pi)*360E-8;show(mu,"=",u)
s=1/(n(pi)*360E+8);show(epsilon,"=",s)
# Out:
# mu '=' 1.14591559026165e-6
# epsilon '=' 8.84194128288307e-12

# %% [markdown]
# Les controverses entre les physiciens, m'ont mis la puce à l'oreille en montrant que l'erreur est humaine !
#
# Leibniz donnait l'équation de la force par $F=mv^2$, alors que Newton donnait $F=\frac{mv^2}{2}$ !
#
# On retrouve ce facteur 2 dans beaucoup d'équations.
