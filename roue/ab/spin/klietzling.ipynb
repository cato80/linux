# %%
# %display latex

# %% [markdown]
# 50 secondes d'arc par an. 12 âge zodiacaux 2160 ans.
# 25920, arrondis à 25800 ans (klitzling : Ko=25800 $\Omega$).15 août 2012 8h du matin ?
#
# 25826.4 pouces pyramidaux, diagonales de la pyramide

# %%
25826.4 /2
# Out:
# 12913.2000000000

# %%
r=2.0/sqrt(n(pi));r
# Out:
# 1.12837916709551

# %%
25826/360.0
# Out:
# 71.7388888888889
