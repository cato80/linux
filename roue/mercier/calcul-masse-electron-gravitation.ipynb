# %%
# %display latex # (4)
c=299792458;a=7.2973525664E-3;Me=9.10938356E-31
h=6.626E-34;hb=h/(2*n(pi));hb=h/(n(pi)*2);
G=6.67384E-11;Lp=sqrt(hb*G/2*n(pi)*c^3);B=(3-sqrt(5.0))
show(LatexExpr(r"L_p=ct_p=\sqrt \frac{h G}{2\pi c^3}\
="),Lp,LatexExpr(r"m"))
# Out:
# L_p=ct_p=\sqrt \frac{h G}{2\pi c^3}\
# = 5.45776296252257e-10 m

# %%
Mp=sqrt(h*c/(2*n(pi)*G)) #(5)
show(LatexExpr(r"M_p=\sqrt \frac{h c}{2 \pi G}\
="),Mp,LatexExpr(r"kg"))
# Out:
# M_p=\sqrt \frac{h c}{2 \pi G}\
# = 2.17649782635443e-8 kg

# %% [markdown]
# Postulat : L’électron est la particule élémentaire qui possède la masse au repos la plus élevée qui soit.(page 4)

# %%
N=1/a^57;v=((a^2)/((2*B)*N^(1/3)));v # (10)
# Out:
# 8.75764237219760e-46
