# %%
# %display latex
G=6.67384E-11;c=299792458;Re=2.817940E-15;h=6.626E-34
Me=9.10E-31;a=7.297735256698E-3;B=3-sqrt(5.0);Ru=0
Qe=1.60E-19;Roo=10973731;Kb=1.38E-23;Mp=2.176470E-8
Lp=1.61622E-35;ep=8.854157817E-12;mu=4*3.1415E-7
Tp=5.39116E-44;Huk=72.0955481532;Pars=3.244E-20
Mu=1.720E+53;N=1/a^57;Mph=2.471169420E-52

# %% [markdown]
# Calcul de la masse associée au photon au repos
# Claude Mercier ing., 22 mars, 2017
# Rév. 25 juin 2017 claude.mercier@gctda.com
#
# Analyse, calcul et critique de cet excellent article

# %% [markdown]
# Dans le modèle standard, le photon possède une masse nulle. Il est cependant
# possible de lui associer une masse équivalente à son énergie ondulatoire grâce
# aux équations d’Einstein [11] et de Planck [12]. Cette masse est petite et non
# mesurable. Bien qu’il soit entièrement hypothétique de concevoir un photon au repos, nous
# désirons calculer sa masse au repos pour en connaître les conséquences.
#
# Cette introduction est ambiguë : Le photon possède une masse nulle, dans ce cas-là $m=0$, l'équation $E=mc^2$ se résout en $E=c^2$
#
# L'Energie est une force $E=F$, ce n'est pas en changeant le mot qu'on modifie l'objet. Le photon a un poids $E=c^2$ = 89875517873681764 Newton et kg = 8987551787368176.4 kg = 8.9875517873681764 Peta grs
#
# Donc l'énergie d'un bi-photon est 8.9875517873681764 Pg

# %%
c=299792458;cc=c^2;round(cc,16)
# Out:
# 8.987551787368176e+16

# %%
show(round(cc,16)," 8.987551787368176Peta grsKg")
# Out:
# 8.987551787368176e+16 ' 8.987551787368176Peta grsKg'

# %%
cc
# Out:
# 89875517873681764

# %%
show(LatexExpr(r"E=hf=\frac{hc}{\lambda}")); #page3
# Out:
# E=hf=\frac{hc}{\lambda}

# %%
show(LatexExpr(r"\lambda=\frac{c}{f}"))
# Out:
# \lambda=\frac{c}{f}

# %%
show(LatexExpr(r"\omega_c=\frac{1}{\sqrt(\mu\epsilon)}"))
# Out:
# \omega_c=\frac{1}{\sqrt(\mu\epsilon)}

# %%
show(LatexExpr(r"\omega_f=2\pi f"))
# Out:
# \omega_f=2\pi f

# %%
show(LatexExpr(r"f=\frac{\omega}{2\pi}=\frac{1}{2}"))
# Out:
# f=\frac{\omega}{2\pi}=\frac{1}{2}

# %%
show(LatexExpr(r"f=\frac{\omega}{2\pi}"))
# Out:
# f=\frac{\omega}{2\pi}

# %%
show(LatexExpr(r"\lambda=2\pi"))
# Out:
# \lambda=2\pi

# %% [markdown]
# Il apparait que la longueur d'onde et la période sont identique d'où redondance, menant à $\lambda=cT=ct$
#
# $f \pm$ inverse de $T\pm $ et inverse, c'est exactement la définition du yin $x$  et yang $y $

# %%
Lo=sqrt((h*G)/(6.28*c^3));Lo
# Out:
# 1.61660059684145e-35

# %%
m=sqrt((h*c)/(6.28*G));m
# Out:
# 2.17704973202876e-8

# %%
Ru=1.28E+26;Mph=(h/(6.28*Ru*c));Mph
# Out:
# 2.74954679386813e-69

# %%
Hu=4.26962041853635E+17;Ho=1/Hu
Ru=c/Ho

# %%
N=Mu/Mph;N # 2piE+121
# Out:
# 6.25557638748262e121

# %%
Ev=c/(2*N);Ev# quantum de vitesse m/s
# Out:
# 2.39620172011554e-114

# %%
G=(c^2*Re*a^20)/(Me*B);G=6.67322980986E-11

# %%
Hub=((c*a^19)*sqrt(B))/Re;Pars=Hub/72.0955481532;Pars
H0=Hub/Pars;H0
# Out:
# 72.0955481532000

# %%
show(LatexExpr(r"p=\frac{h}{\lambda}")) # lambda 2pi
# Out:
# p=\frac{h}{\lambda}

# %%
B*c*sqrt(2-B^2)
# Out:
# 2.72564683355185e8

# %%
299792458/272564683.3
# Out:
# 1.09989472726381

# %%
D=(8*3.1415*G*2.232E-27)/c^2;D
# Out:
# 4.16500873548016e-53

# %%
Pa=(2.232E-27*H0^2)/((8*3.1415)*G);Pa
# Out:
# 6.91748067314005e-15

# %%
Pg=2.232E-27

# %%
Ga=D;Ga
# Out:
# 4.16500873548016e-53

# %%
D=(8*3.1415*G*2.232E-27)/c^2;D
# Out:
# 4.16500873548016e-53

# %%
tan(4*arctan(1/5)).simplify_trig()
# Out:
# 120/119

# %%
tan(pi/4+arctan(1/239)).simplify_trig()
# Out:
# 120/119

# %%
f = arctan(x).series(x, 10); f
# Out:
# 1*x + (-1/3)*x^3 + 1/5*x^5 + (-1/7)*x^7 + 1/9*x^9 + Order(x^10)

# %%
show((16*f.subs(x==1/5) - 4*f.subs(x==1/239)).n())
show(pi.n())
# Out:
# 3.14159268240440
# 3.14159265358979

# %%
diff(sin(x^2), x)
# Out:
# 2*x*cos(x^2)

# %%
(1+i)*(1-i)
# Out:
# 2

# %%
U = 2.0; V = 50.0;
while V-U >= 1.0e-6:
# remplace le rationnel 10^-6 p73 sage-book
    temp = U
    U = 2 * U * V / (U + V)
    V = (temp + V) / 2
U, V
# Out:
# (9.99999999989256, 10.0000000001074)

# %%
u = 6 ; n = 0
while u != 1:
# test "différent de" <> aussi possible
    if u % 2 == 0:# l'opérateur % est le reste euclidien
        u = u/2
    else:
        u = 3*u+1
    n = n+1
n
# Out:
# 8
