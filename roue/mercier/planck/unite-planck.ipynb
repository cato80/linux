# %% [markdown]
# ##### Calcul interprétations unité planck  (Mercier p2/3)
#
# Dans un deuxième énoncé, Heisenberg nous apprend que l’incertitude sur la mesure de l’énergie d’un corps est inversement proportionnelle à la durée de la mesure. Une autre manière de formuler cet énoncé est de dire que le produit de l’énergie ∆E par le temps ∆t doit être :
#
# $\Delta E\cdot \Delta t \ge \frac{h}{2} $
#
# Y a un problème, car ôté $\pi$ revient à ôté la longueur d'onde fondamentale $\lambda=2\pi$

# %% [markdown]
# Les unités de Planck simplifient plusieurs équations de physique en supprimant des facteurs de conversion. Voici quelques exemples (à gauche, les équations de
# base et à droite, les équations montrées en unités de Planck) : L'équation de gravitation universelle de Newton devient :
#
# $F=\frac{-Gm_1m_2}{r^2}$ $\iff$ $F=\frac{-m_1m_2}{r^2}$$\iff$ $F=\frac{-1}{r^2}$

# %%
# %display latex
G=6.67384E-11;c=299792458;Re=2.817940E-15;
h=6.626E-34
Me=9.10E-31;a=7.297735256698E-3;B=3-sqrt(5.0);Ru=0
Qe=1.60E-19;Roo=10973731;Kb=1.38E-23;Mp=2.176470E-8
Lp=1.61622E-35;ep=8.854157817E-12;mu=4*3.1415E-7
Tp=5.39116E-44

# %%
G0=c^2*Re*a^20/(Me*B);G0
# Out:
# 6.68712011993901e-11

# %%
hb=h/(2*n(pi));hb
# Out:
# 1.05456065292690e-34

# %%
Ed=(h/hb)/2;show(Ed) # incertitude
# Out:
# 3.14159265358979

# %% [markdown]
# (p4) Ce rayon est celui d’un trou noir. Pour ce rayon, la vitesse de la lumière devient nulle. En isolant $m_0$ , nous obtenons : $m_0=\frac {rc^2}{2G}$

# %%
H0=(c*(a^19)*(sqrt(B)))/Re;show(H0)
# Out:
# 2.33878499444856e-18

# %%
show(LatexExpr(r"\Delta E=\frac{(\frac{h}{\hbar})}{2}=\pi"))
# Out:
# \Delta E=\frac{(\frac{h}{\hbar})}{2}=\pi

# %%
Ru=1.28E+26;Tu=Ru/c;Tu
# Out:
# 4.26962041853635e17

# %%
Hu=Ru/c;show("Hubble=",Hu)
# Out:
# 'Hubble=' 4.26962041853635e17

# %%
Ho=Hu
Ru=c*Ho;show("Rayon courbure=",Ru)
# Out:
# 'Rayon courbure=' 1.28000000000000e26

# %%
Mu=c^3/G*Ho;show("Mass Univ=",Mu)
# Out:
# 'Mass Univ=' 1.72375518259821e53

# %%
Mp=sqrt(h*c^3/2*n(pi)*G);show("Mu planck=",Mp)
# Out:
# 'Mu planck=' 1.36805829580929e-9

# %%
Mph=(h*Ho)/(n(2*pi)*c^2);show("Mph=",Mph)
# Out:
# 'Mph=' 5.00978887559790e-34

# %%
Qe=-sqrt(4*n(pi)*Re*Me/4*n(pi)*1E-7);show("Qe=",Qe)
# Out:
# 'Qe=' -5.03079290506628e-26

# %%
G=6.67384E-11;c=299792458;Re=2.817940E-15;h=6.626E-34
Me=9.10E-31;a=7.297735256698E-3;B=3-sqrt(5.0);
mu=n(pi)*4E-7;p4=4*n(pi)

# %%
Mx=(mu*(Qe^2)*(sqrt(B)))/(n(pi)*4)*Re*a^39;show("Mu/Qe=",Mx)
# Out:
# 'Mu/Qe=' 2.87784926743098e-156

# %%
Roo=a^3/p4*Re;show("Roo=",Roo)
# Out:
# 'Roo=' 8.71537724786638e-23

# %%
cTu=c/(1/Ho);show("cTu=",cTu)
# Out:
# 'cTu=' 1.28000000000000e26

# %%
Rcu=Re/(a^19*sqrt(B));show("Ru=",Rcu)
# Out:
# 'Ru=' 1.28182991900324e26

# %%
#Reo=Qe^2*mu/p4*Me*a^19*sqrt(B);Reo

# %%
#p13 rayon apparent univers

# %%
Ra=B*Ru;Ra# 9.80 E25 voire 9.87E25 carré de pi
# Out:
# 9.77832988800269e25

# %%
n(pi)^2*1E25
# Out:
# 9.86960440108936e25

# %%
c*Ho
# Out:
# 1.28000000000000e26

# %%
c*(Ho/B)
# Out:
# 1.67554175279993e26

# %% [markdown]
# Dirac(Mercier) p4

# %%
ep=1/(mu*c^2)
E2=Qe^2/(ep*p4*G*Me^2);E2
# Out:
# 4.11581371623931e29

# %%
H0=G*sqrt(2*n(pi)*Me^3*B^3/h*c*Re^3*a^3);H0
# Out:
# 6.08239038164819e-60

# %%
E=c^2;E
# Out:
# 89875517873681764

# %%
mt=(Ho*hb^2/G*c)^(1/3);mt
# Out:
# 2.77327179739955e-11

# %%
1/(1.6021765651E-19)
# Out:
# 6.24150934287062e18

# %%
3.1415/2
# Out:
# 1.57075000000000

# %%
1/(2*n(pi)*1E-20)
# Out:
# 1.59154943091895e19

# %%
Mu=c^3/G*Ho;Mu
# Out:
# 1.72375518259821e53

# %%
Ru=c*Ho;Ru
# Out:
# 1.28000000000000e26

# %%
Hu=(1/Ho);Hu
# Out:
# 2.34212857812500e-18

# %%
Ur=B*c/Hu;Ur
# Out:
# 9.77832988800269e25

# %%
Tu=1/(Hu/B*c);Tu
# Out:
# 1.08798592979970e9

# %%
Mph=(h*c)/(6.28*Ru);Mph
# Out:
# 2.47116942016819e-52

# %%
G=((c^2)*Re*a^20)/(Me*B);G
# Out:
# 6.68712011993901e-11

# %%
Hub=((c*a^19)*sqrt(B))/Re;Hub
# Out:
# 2.33878499444856e-18

# %%
Pars=Hub/72.0955481532;Pars
# Out:
# 3.24400750720244e-20

# %%
HuKm=Hub/Pars;HuKm # Hubble parsec/s
# Out:
# 72.0955481532000

# %%
Lp=Re*sqrt(a^19/B);Lp
# Out:
# 1.61693057850797e-35

# %%
Mp=Me*sqrt(B/a^21);Mp
# Out:
# 2.17316977267818e-8

# %%
Tp=(Me*c^2/Kb)*sqrt(B/a^21);Tp #K°
# Out:
# 1.41532433874553e32

# %%
Qe=1.60E-19
Qp=-Qe*sqrt(1/0.0072);Qp
# Out:
# -1.88561808316413e-18

# %%
N=6.30E+121
Mph=2.74E-69

# %%
Mu=c^3/G*Ho;show("Mass Univ=",Mu)
Nc=Mu*Mph;Nc
# Out:
# 'Mass Univ=' 1.72033193385140e53
# 4.71370949875283e-16

# %%
Mu/Mp
# Out:
# 7.91623349210902e60

# %%
sqrt(N)
# Out:
# 7.93725393319377e60

# %%
Na=1/a^57 # 2piE+121

# %%
Pi2=n(pi,digits=121)*2;Pi2
# Out:
# 6.283185307179586476925286766559005768394338798750211641949889184615632812572417997256069650684234135964296173026564613294

# %%
Npi=2*n(pi)*1E121

# %%
Npi-(N/2)
# Out:
# 3.13318530717959e121

# %%
Na-Pi2
# Out:
# 6.28460605965532e121

# %%
Na2=Na/2

# %%
2-(1/(Na2/Pi2))
# Out:
# 2.00000000000000
