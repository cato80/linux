# %% [markdown]
# http://www.cfm.brown.edu/people/dobrush/am34/sage/linalg.html

# %%
l1=line([(-2,-1/3), (3,4/3)],thickness=2,color="black")
l2=line([(1,3), (3,-1)],thickness=2,color="black")
ah = arrow((-2.4,0), (3.4,0),arrowsize=2)
av = arrow((0,-1), (0,3),arrowsize=2)
P=circle((2.0,1.0),0.04, rgbcolor=hue(0.75), fill=True)
t1=text(r"$(2,1)$",(2.25,0.95))
t2=text(r"$x-3y=1$",(1.0,0.9))
t2=text(r"$x-3y=1$",(1.0,0.9))
t3=text(r"$2x+y=5$",(1.8,2.1))
show(l1+l2+ah+av+t1+t2+t3+P,axes_labels=['$x$','$y$'],
     gridlines="Major",frame=True,fontsize=8)
# Out:
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2327: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   x_formatter = OldScalarFormatter()
# /usr/lib/python3/dist-packages/sage/plot/graphics.py:2352: MatplotlibDeprecationWarning:
# The OldScalarFormatter class was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   y_formatter = OldScalarFormatter()
# Graphics object consisting of 8 graphics primitives

# %%
ah = arrow((-3.1,0), (2.2,0),arrowsize=2)
av = arrow((0,-0.2), (0,5.1),arrowsize=2)
a1=arrow([0,0],[-3,1], width=2, arrowsize=2,color="black")
a2=arrow([0,0],[1,2], width=2, arrowsize=2,color="black")
a3=arrow([0,0],[2,4], width=2, arrowsize=2,color="black")
a4=arrow([0,0],[-1,5], width=2, arrowsize=2,color="black")
l1=line([(-3,1), (-1,5)],color="blue",linestyle="dashed")
l2=line([(2,4), (-1,5)],color="blue",linestyle="dashed")
t1=text(r"${\bf v}_1$",(-3,0.85),color="black")
t2=text(r"${\bf v}_2$",(1.1,1.85),color="black")
t3=text(r"$2{\bf v}_2$",(2.05,3.75),color="black")
t4=text(r"${\bf v}_1 + 2{\bf v}_2$",(-1.5,4.8),
        color="black",fontsize=12)
show(av+ah+a1+a2+a3+a4+l1+l2+t1+t2+t3+t4,
axes_labels=['$x$','$y$'],gridlines="Major",
     fontsize=8,frame=True)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
l1=line([(-2,-1/3), (3,4/3)],thickness=2,color="black")
l2=line([(-2,1), (3,1)],thickness=2,color="black")
ah = arrow((-2.4,0), (3.4,0),arrowsize=2)
av = arrow((0,-1), (0,1.5),arrowsize=2)
P=circle((2.0,1.0),0.03, rgbcolor=hue(0.75), fill=True)
t1=text(r"$(2,1)$",(2.25,0.85))
t2=text(r"$x-3y=1$",(0.6,0.7))
t3=text(r"$7y=7$",(1.5,1.1))
show(l1+l2+ah+av+t1+t2+t3+P,axes_labels=['$x$','$y$'],
     fontsize=8,frame=True,gridlines="major")
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
A = matrix([[1,2],[2,1]])
vecs = A.eigenvectors_right()
v = vecs[0][1][0]
show("A = ",A)
show("v = ",v)
show("A*v = ",A*v)
plot(A*v) + plot(v, color="red", 
aspect_ratio=1, figsize=4, gridlines=True)
# Out:
# 'A = ' [1 2]
# [2 1]
# 'v = ' (1, 1)
# 'A*v = ' (3, 3)
# Graphics object consisting of 2 graphics primitives

# %%
A = matrix([[1,2],[2,1]]);A
# Out:
# [1 2]
# [2 1]

# %%
show(((2+0*i)^(3+0*i))^2)
# Out:
# 64

# %%
l1=line([(1,0), (1,1)],thickness=2,color="red",
       linestyle="--")
l2=line([(0,1), (1,1)],thickness=2,color="red",
       linestyle="--")
ah = arrow((0,0), (1.2,0),arrowsize=2)
av = arrow((0,0), (0,1.2),arrowsize=2)
a3 = arrow((0,0), (1,1),arrowsize=2,color="green")
P=circle((1.0,1.0),0.02, rgbcolor=hue(0.90), fill=True)
t1=text(r"$0$",(0,0))
t2=text(r"$0$",(0,0))
t3=text(r"0",(0,0))
show(l1+l2+ah+av+t1+t2+t3+P+a3,axes_labels=['$x$','$y$'],
     fontsize=8,frame=True,gridlines="minor")
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
8/8.10
# Out:
# 0.987654320987654

# %%
sqrt(9.87)
# Out:
# 3.14165561448100

# %% [markdown]
# La quadrature du cercle est 4, les constantes physique, lumière, perméabilité sont 4$\pi$

# %%
L=1/n(pi)*36;L
# Out:
# 11.4591559026165

# %%
C=1/(n(pi)*36);C
# Out:
# 0.00884194128288308

# %% [markdown]
# 0.0036*2

# %% [markdown]
# $\alpha$ est un condensateur de capacité 0.0036*2=0.0072

# %%
C=1/(n(pi)*36)
w=1/sqrt(L*C);round(w*1E+8)
# Out:
# 314159265

# %%
mu=n(pi)*4E-7;c=299792458;ep=1/(mu*c*c);ep,mu
# Out:
# (8.85418781762039e-12, 1.25663706143592e-6)

# %%
L=0.0125663706;C=8.8541878
w=1/sqrt(L*C);round(w*1E+8)
# Out:
# 299792458

# %%
L=0.031415;C=0.6281415
w=1/sqrt(L*C);round(w*1E+8)
# Out:
# 711873333

# %% [markdown]
# Ce que les scientifiques appellent un champ est en réalité un intervalle

# %%
Gauss=2*n(pi) #gravitation selon gauss

# %%
show(LatexExpr(r"1-année-gauss=\frac{2\pi}{k}"))
# Out:
# 1-année-gauss=\frac{2\pi}{k}

# %% [markdown]
# Ils sont complètement tarés = 499s*c =500 conviendrait mieux

# %% [markdown]
# %display latex
# deg(x)=x*180/n(pi);deg(1)

# %%
deg(0.866)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f20f84214805> in <module>
# ----> 1 deg(RealNumber('0.866'))
#
# NameError: name 'deg' is not defined

# %%
rad(x)=x*n(pi)/180;rad(60)

# %% [markdown]
# On choisira celle qui produit un facteur gamma de 2 exactement, soit 86,6 % (sin 60°) de la vitesse de la lumière.

# %% [markdown]
# https://www.collectionscanada.gc.ca/eppp-archive/100/200/300/gabriel_lafreniere/matiere_ondes-e/lumiere.htm

# %% [markdown]
# laser 2 mm à 600 nm = disque d'airy 2mm à 2.732

# %%
L=4.0/(2.44*600)*1000;show(L," m")

# %% [markdown]
# https://www.collectionscanada.gc.ca/eppp-archive/100/200/300/gabriel_lafreniere/matiere_ondes-e/optique/airy.htm
#
# ![image.png](attachment:image.png)
