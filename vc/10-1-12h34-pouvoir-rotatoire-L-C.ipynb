# %%
cc=circle((0,0),3.141592653);cc
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
cv=circle((0,0),2.99792458,color="red");cv
show(cv+cc)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
vc=circle((0,0),1.047,color="green");vc
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(cv+cc+vc)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
ve=circle((0,0),2.55,color="violet");
show(cv+cc+vc+ve)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
pp=n(pi,digits=33);pq=1/pp;pq
# Out:
# 0.318309886183790671537767526745029

# %%
pp/6
# Out:
# 0.523598775598298873077107230546584
