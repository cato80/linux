# %%
# %display latex
import warnings;warnings.filterwarnings(
"ignore",category=DeprecationWarning)

# %% [markdown]
# $\lambda=\frac{\frac{1}{\sqrt\mu\epsilon}}{\frac{1}{2\pi\sqrt\mu\epsilon}}$ = $\frac{c}{\nu}$=$2\pi$

# %%
show(LatexExpr(r"\lambda=\frac{\frac{1}{\sqrt\mu\epsilon}}{\frac{1}{2\pi\sqrt\mu\epsilon}} = \frac{c}{\nu}=2\pi"));
# Out:
# \lambda=\frac{\frac{1}{\sqrt\mu\epsilon}}{\frac{1}{2\pi\sqrt\mu\epsilon}} = \frac{c}{\nu}=2\pi

# %%
show(LatexExpr(r"r_e=\frac{1}{4\pi \epsilon_0}\frac{e^2}{m c^2} = 2.817940325 \times 10^{-15} m "));
# Out:
# r_e=\frac{1}{4\pi \epsilon_0}\frac{e^2}{m c^2} = 2.817940325 \times 10^{-15} m

# %%
mu=4*3.141592653E-7;c=299792458;ep=1/(mu*c*c)
e=1.60E-19;m=9.10E-31;k=1/(ep*(mu/1E-7))
Re=(1/k)*(e^2/m*c^2);Re=2.817940E-15
