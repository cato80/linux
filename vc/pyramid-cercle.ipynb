# %%
# %display latex
r=2/sqrt(n(pi))
f(x)=sqrt(r^2-x^2);r
# Out:
# 1.12837916709551

# %%
c=r*sqrt(1-(x/r)^2);c
# Out:
# 1.12837916709551*sqrt(-0.785398163397448*x^2 + 1)

# %%
deg(x)=x*180/n(pi);deg(0.785398163397448)
# Out:
# 45.0000000000000

# %%
c=n(pi)/6;r=sqrt(2.0);cp=c*r*n(pi)*439.995154;cp
# Out:
# 1023.55547608840

# %%
rp=c*n(pi)*440;rp
# Out:
# 723.770989413219

# %%
cc=439.995154;lc=cr*cc*n(pi)
ll=cr*cc*r*n(pi);ll
# Out:
# 1023.55547608840

# %%
(cp-rp);c*440;cr=n(pi)/6;ll-lc
# Out:
# 299.792458025667

# %%
299792458-299795759.867149
# Out:
# -3301.86714899540

# %%
p1=arc((0,0),1,angle=pi/7,sector=(pi/-7,pi/9))
x=x;p=plot(x*1,x,0,0.71,color="green")
l1=line(((1,0),(0.71,0.71)),color="black",        
thickness=1,linestyle="--")
show(p+p1+l1,gridlines="minor",
     figsize=5,fontsize=5);
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
ci=circle((0,0,),1,color="red")
p1=arc((0,0),1,angle=pi/4,sector=(pi/-4,pi/9))
x=x;p=plot(x*2.14,x,0,0.42,color="green")
show(ci+p+p1,gridlines="minor",figsize=3,fontsize=5)
# Out:
# Graphics object consisting of 3 graphics primitives
