# %% [markdown]
# ###### La clé de zeta
#
# $\zeta$ est une harmonique de $\pi$.

# %%
# %display latex
deg(x)=x*n(pi)/180;
rad(x)=x*180/n(pi);
show(rad(zeta(221.0))==rad(1),"°","degré")
ze=rad(zeta(221.0))
# Out:
# 57.2957795130823 == 57.2957795130823 '°' 'degré'

# %% [markdown]
# en analysant cette solution, j'ai remarqué que je pouvais la simplifier en $\zeta(0)$ =1

# %%
show(rad(zeta(0)*-2))
# Out:
# 57.2957795130823

# %%
zeta(0)
# Out:
# -1/2
