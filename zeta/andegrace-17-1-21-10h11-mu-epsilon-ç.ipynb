# %%
# %display latex
var("t r y x du dx dt")
u=sin(t);du=diff(u);du
# Out:
# cos(t)

# %%
u=x/r;u
# Out:
# x/r

# %%
solve(du==u,x)
# Out:
# [x == r*cos(t)]

# %%
solve(du==x,x)
# Out:
# [x == cos(t)]

# %%
solve(du/dx==1/r,t)
# Out:
# [t == arccos(dx/r)]

# %%
solve(du/dx==1/r,du)
# Out:
# [cos(t) == dx/r]

# %%
solve(du/dx==1/x,du)
# Out:
# [cos(t) == dx/x]

# %%
from sage.symbolic.integration.integral import definite_integral

# %%
g(x)=sqrt(1-x^2)
a = integral(g(x), x, 0, r, hold=True) ; a
# Out:
# integrate(sqrt(-x^2 + 1), x, 0, r)

# %%
f(x)=sqrt(r^2-x^2);Ig=integral(f(x), x, 0, r, hold=True);Ig
# Out:
# integrate(sqrt(r^2 - x^2), x, 0, r)

# %%
cx=r*sqrt(1-(x/r)^2)
cg=integral(cx, x, 0, r, hold=True);cg
# Out:
# integrate(r*sqrt(-x^2/r^2 + 1), x, 0, r)

# %%
show(cx,hold=False)
# Out:
# r*sqrt(-x^2/r^2 + 1)

# %%
solve(cx==0,x)
# Out:
# [x == -r, x == r]

# %%
solve(cx==x,x)
# Out:
# [x == r*sqrt((r^2 - x^2)/r^2)]

# %%
u,du(t)
# Out:
# (sin(x), cos(t))

# %%
u=sin(x);u,du
# Out:
# (sin(x), cos(t))

# %%
zeta(2.0)/6
# Out:
# 0.274155677808038

# %%
deg(x)=x*n(pi)/180;deg(0.274155677808038)
# Out:
# 0.00478491924078701

# %%
rad(x)=x*180/n(pi);rad(0.274155677808038)
# Out:
# 15.7079632679490

# %%
rad(x)=x*360/n(pi);rad(0.274155677808038)/10
# Out:
# 3.14159265358980

# %%
(n(pi)*2)
# Out:
# 6.28318530717959

# %%
rad(0.274155677808038)*2/10
# Out:
# 6.28318530717959

# %%
zeta(2)
# Out:
# 1/6*pi^2

# %%
zeta(2)*6
# Out:
# pi^2

# %%
zeta(2.0)/6
# Out:
# 0.274155677808038

# %%
zeta(2)/6
# Out:
# 1/36*pi^2

# %%
rad(0.274155677808038)
# Out:
# 31.4159265358980
