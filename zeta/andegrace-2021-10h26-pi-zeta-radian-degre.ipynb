# %% [markdown]
# La fonction zeta fait couler beaucoup d'encre, pourtant elle est simplement une résonance de $\pi$.
#
# Voici une solution possible :
#
# %display latex : Permet d'afficher en latex
#
# Définition de la fonction degré et radian.

# %%
# %display latex
deg(x)=x*n(pi)/180;
rad(x)=x*180/n(pi);
show(rad(zeta(221.0))==rad(1),"°","degré")
ze=rad(zeta(221.0))
# Out:
# 57.2957795130823 == 57.2957795130823 '°' 'degré'

# %%
zeta(2.0)
# Out:
# 1.64493406684823

# %%
rad(1)
# Out:
# 57.2957795130823

# %%
show(1,LatexExpr(r" rad = "),rad(1),"°")
# Out:
# 1  rad =  57.2957795130823 '°'

# %%
deg(27)
# Out:
# 0.471238898038469

# %%
show(LatexExpr(r"\zeta (221.0)="),ze," = 1 rad=",rad(1)," degré")
# Out:
# \zeta (221.0)= 57.2957795130823 ' = 1 rad=' 57.2957795130823 ' degré'

# %%
z1=deg(zeta(221.0));1/z1
# Out:
# 57.2957795130823

# %%
(factorial(6)*z1/4)
# Out:
# 3.14159265358979

# %%
n(pi,digits=35)
# Out:
# 3.1415926535897932384626433832795029

# %%
2*n(pi)/deg(6)
# Out:
# 60.0000000000000

# %%
int(2*n(pi)*rad(1))
# Out:
# 360

# %% [markdown]
# page 2 problème de Bâle $1-\frac {1}{n}$
#
# Fresnel $\alpha= 1-\frac {1}{n^2} $
